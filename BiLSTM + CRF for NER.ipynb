# %% [markdown]
# # BiLSTM + CRF for NER
# BiLSTM的输入时文档向量, 并不需要对文档向量padding到一致的长度, 因为对应1个文档, BiLSTM输出1个feats矩阵(len_doc, num_tag), 将feats矩阵输入CRF, CRF最主要是要训练其转移矩阵(tag->tag), 所以即使feats矩阵行数不一, CRF都能用feats训练转移矩阵
#
# 官方实现: https://pytorch.apachecn.org/docs/1.0/nlp_advanced_tutorial.html?h=Bidirection

# %%
import keras
from keras.models import Sequential
from keras.layers import *
import nltk
import torch.nn as nn
import torch
# Out:
# D:\study\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## 数据准备

# %%
num_sentence = 10000
with open(r'D:/CS/dataset/NLP/命名实体识别/单个字特征数据集/example.train', 'r', 
          encoding='utf-8') as f:
    i = 0;
    a = []
    while(i < num_sentence):     # 读取了10000句预料
        content = f.readline()
        if content == '\n':
            i += 1
        a.append(content)

# %%
def get_sentences(temp_list):
    index_list = []
    for i in range(len(temp_list)):
        if temp_list[i] == '\n':
            index_list.append(i)
    
    pointer = 0
    sentence_list = []
    for index in index_list:
        sentence_list.append(temp_list[pointer : index])
        pointer = index + 1
    return sentence_list

# %%
sentence_list = get_sentences(a)

# %%
sentence_list[-2]   # 最后一句没有句号
# Out:
# ['但 O\n',
#  '是 O\n',
#  '， O\n',
#  '金 O\n',
#  '融 O\n',
#  '危 O\n',
#  '机 O\n',
#  '也 O\n',
#  '可 O\n',
#  '能 O\n',
#  '来 O\n',
#  '自 O\n',
#  '内 O\n',
#  '部 O\n',
#  '。 O\n']

# %%
# 去掉'\n'和句号
for sentence in sentence_list:
    try:
        sentence.remove('。 O\n')
    except:
        pass
    
    for i in range(len(sentence)):
        sentence[i] = tuple(sentence[i].strip('\n').split(' '))

# %%
sentence_list[-1]
# Out:
# [('首', 'B-ORG'),
#  ('届', 'I-ORG'),
#  ('立', 'I-ORG'),
#  ('法', 'I-ORG'),
#  ('会', 'I-ORG'),
#  ('选', 'O'),
#  ('举', 'O'),
#  ('是', 'O'),
#  ('“', 'O'),
#  ('港', 'B-LOC'),
#  ('人', 'O'),
#  ('治', 'O'),
#  ('港', 'B-LOC'),
#  ('”', 'O'),
#  ('重', 'O'),
#  ('要', 'O'),
#  ('一', 'O'),
#  ('步', 'O')]

# %%
# 去除特殊符号
stop_words = '[a-zA-Z0-9’\n·\s＊!"：#$%&\'()◆●（）＠②*+,-./:;<=>?@，。?★、…【】《》？——“”‘’！[\$$^_`{|}~]+'
sentence_list = [[(word, tag) for word, tag in sentence if word not in stop_words] for sentence in sentence_list]

# %%
sentence_list[-1]
# Out:
# [('首', 'B-ORG'),
#  ('届', 'I-ORG'),
#  ('立', 'I-ORG'),
#  ('法', 'I-ORG'),
#  ('会', 'I-ORG'),
#  ('选', 'O'),
#  ('举', 'O'),
#  ('是', 'O'),
#  ('港', 'B-LOC'),
#  ('人', 'O'),
#  ('治', 'O'),
#  ('港', 'B-LOC'),
#  ('重', 'O'),
#  ('要', 'O'),
#  ('一', 'O'),
#  ('步', 'O')]

# %% [markdown]
# ## 准备数据

# %%
from gensim.corpora.dictionary import Dictionary
from keras.preprocessing import sequence
# Out:
# D:\study\Anaconda\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
docs = [[word for word, tag in sentence] for sentence in sentence_list]

# %%
# 总词数
dic = Dictionary(docs)
vocab_size = max(dic.keys()) + 1
print('总词数: ', vocab_size)     # 词id从0开始, 最大id 3818

# 寻找最大句长
sentences_len = [len(doc) for doc in docs]
max_len_a_doc = max(sentences_len)
print('最大文档长度', max_len_a_doc)
# Out:
# 总词数:  3819
# 最大文档长度 550

# %% [markdown]
# 查看sentences_len发现绝大多数文档长度在120以内

# %%
max_len_a_doc = 120
trainY = [[tag for word, tag in sentence] for sentence in sentence_list]    # padding之前

my_dic = dict([('O',0), ('B-LOC', 1), ('I-LOC', 2),
            ('B-PER', 3), ('I-PER', 4), ('B-ORG', 5), ('I-ORG', 6)])
def tag2idx(tag):
    return my_dic[tag]

# 先将tag映射为idx, 再对idx序列padding, 由于'O'对应idx为0, 所以句子padding部分都视作'O', 对应数字0
# 不能用padding, 会使 B-LOC, I-LOC 都变成 B, I
trainY_vec = [[my_dic[tag] for tag in sentence] for sentence in trainY]
trainY = trainY_vec
# trainY_vec = sequence.pad_sequences(trainY_vec, maxlen=max_len_a_doc, value=0, padding='post')
# trainY_vec = torch.LongTensor(trainY_vec)
# trainY_vec[0]

# %%
from sklearn.preprocessing import LabelBinarizer
import numpy as np

# %%
# 文本向量化
doc_vec_list = [dic.doc2idx(doc) for doc in docs]
trainX = doc_vec_list
# trainX = torch.LongTensor(doc_vec_list)
# trainY = trainY_vec
# 不能填充-1 因为embedding矩阵中没有-1索引
# padded_doc_vec_list = sequence.pad_sequences(doc_vec_list, maxlen=120, value=3819, padding='post')
# trainX = np.array(padded_doc_vec_list)
# trainX[0]

# %% [markdown]
# ## BiLSTM
# 获取BiLSTM的输出feats

# %%
from torch import nn
import torch
from sklearn.preprocessing import LabelBinarizer

# 每次丢入1个句子训练
class BiLSTM_CRF(torch.nn.Module):
    def __init__(self, vocab_size, num_tag, embedding_dim, lstm_dim):  # vocab_size + padding的-1
        super(BiLSTM_CRF, self).__init__()
        self.vocab_size = vocab_size
        self.tag2idx_dict = dict([('O',0), ('B-LOC', 1), ('I-LOC', 2), ('B-PER', 3), ('I-PER', 4), ('B-ORG', 5), ('I-ORG', 6)])
        self.num_tag = len(self.tag2idx_dict.keys())
        
        # transitions[i][j] : 从标签j转移到标签i的分数, 为什么不是从i到j?
        # 因为每个时间步都要对某标签取上一时间步所有标签对该标签的转移分数, 转置后方便取一行
        # 不转置的话就要取transitions的1列
        self.transitions = nn.Parameter(torch.randn(self.num_tag, self.num_tag))
        
        # BiLSTM部分
        self.embedding_dim = embedding_dim
        self.word_embeds = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, lstm_dim, num_layers=1, bidirectional=True)
        self.lstm2tag = nn.Linear(lstm_dim*2, num_tag)   # BiLSTM 会把正反向lstm每个时间步的输出拼接为1行

#     def forward(self, x):
#         x = self.word_embeds(x)
#         x, hidden = self.lstm(x)
#         x = self.lstm2tag(x)
#         return x

    # 总的发射分数 == feats矩阵 * num_tag, 每个时间步的每个tag会被num_tag条路径经过
    # 总的转移分数
    
    def get_lstm_out(self, sentence_in):     # 发射分数
        embeds = self.word_embeds(sentence_in)
        lstm_out, lstm_hidden = self.lstm(embeds)
        feats = self.lstm2tag(lstm_out)
        # LSTM的输出是3D, feats[i]对应第i个句子的feats, 1次只训练1个句子, 所以直接取0转化为2D
        return feats[0]
    
    def get_loss(self, sentence_in, true_tags):
        feats = self.get_lstm_out(sentence_in)
        loss = self.global_score(feats) - self.given_tags_score(feats, true_tags)
        return loss
    
    def given_tags_score(self, feats, true_tags):      # 计算正确路径所得分数
        # 发射分数的计算采用矩阵
        '''
        true_tags: [0,4,2,1,5,6]   1个句子的标签序列, list
        '''
        lb = LabelBinarizer().fit(list(range(self.num_tag)))   # fit [0,1,2,3,4,5,6]
        tag_mat = torch.Tensor(lb.transform(true_tags))    # 每一行对应标签为1, 其余0
        emit_score = torch.mul(feats, tag_mat)         # 标签矩阵与feats对应点相乘
        emit_score = torch.sum(emit_score)
        
        trans_score = 0.0
        for i in range(1, len(true_tags)):
            a = true_tags[i]
            b = true_tags[i-1]
            trans_score += self.transitions[a][b]
            
        return emit_score + trans_score
    
    def log_exp(self, scores):
        return torch.log(torch.exp(scores))
    
    def global_score(self, feats):
        step_scores = feats[0]   # 初始化为第一个时间步的各标签发射概率
        for i in range(1, feats.shape[0]):
            # 每一时间步的每个标签都会加上发射分数
            step_scores += feats[i]
            for tag_idx in range(self.num_tag):
                # 每一时间步每个标签都加上上一个时间步每个标签对该标签的转移分数
                step_scores[tag_idx] += torch.sum(self.transitions[tag_idx])
        
        return torch.sum(step_scores)   # 会溢出

# %% [markdown]
# $$
# \operatorname{Loss}=\log \left(\sum_{\hat{y} \in Y_{X}} e^{S(X, \hat{y})}\right)-S(X, y)
# $$
# global_scores()返回等号右边第一项, 经过了数学变换所以与公式上的看起来不一样

# %% [markdown]
# ## 训练BiLSTM + CRF

# %%
embedding_dim = 64
lstm_dim = 128
num_tag = 7
BiLSTM_CRF_model = BiLSTM_CRF(vocab_size, num_tag, embedding_dim, lstm_dim)

optimizer = torch.optim.RMSprop(BiLSTM_CRF_model.parameters(), lr=0.01, weight_decay=1e-4)
epochs = 1

# 由于是1句1句训练的, 句子不定长, 每次取出句子训练要先化为tnsor
def sentence2tensor(non_tensor_sentence):
    return torch.LongTensor(non_tensor_sentence)

loss = 0.0
for i in range(epochs):
    for j in range(len(trainX[:2000])):
        x = sentence2tensor(trainX[j:j+1])
        loss = BiLSTM_CRF_model.get_loss(x, trainY[j])
        print(loss,'\n')
        loss.backward()
        optimizer.step()
# Out:
# tensor(-70.9691, grad_fn=<SubBackward0>)
#
# tensor(-521.4917, grad_fn=<SubBackward0>)
#
# tensor(-3068.4033, grad_fn=<SubBackward0>)
#
# tensor(-2653.6165, grad_fn=<SubBackward0>)
#
# tensor(-3972.8896, grad_fn=<SubBackward0>)
#
# tensor(-5465.9619, grad_fn=<SubBackward0>)
#
# tensor(-5095.4146, grad_fn=<SubBackward0>)
#
# tensor(-5512.6152, grad_fn=<SubBackward0>)
#
# tensor(-8703.5879, grad_fn=<SubBackward0>)
#
# tensor(-28062.7656, grad_fn=<SubBackward0>)
#
# tensor(-20681.3496, grad_fn=<SubBackward0>)
#
# tensor(-27650.3477, grad_fn=<SubBackward0>)
#
# tensor(-19349.7793, grad_fn=<SubBackward0>)
#
# tensor(-97163.6016, grad_fn=<SubBackward0>)
#
# tensor(-73273.3281, grad_fn=<SubBackward0>)
#
# tensor(-36614.6094, grad_fn=<SubBackward0>)
#
# tensor(-21915.1445, grad_fn=<SubBackward0>)
#
# tensor(-55478.2461, grad_fn=<SubBackward0>)
#
# tensor(-68601.2656, grad_fn=<SubBackward0>)
#
# tensor(-60168.0547, grad_fn=<SubBackward0>)
#
# tensor(-42618.2656, grad_fn=<SubBackward0>)
#
# tensor(-39760.6953, grad_fn=<SubBackward0>)
#
# tensor(-54533.5977, grad_fn=<SubBackward0>)
#
# tensor(-61740.2109, grad_fn=<SubBackward0>)
#
# tensor(-33774.0859, grad_fn=<SubBackward0>)
#
# tensor(-22687.3828, grad_fn=<SubBackward0>)
#
# tensor(-47854.5703, grad_fn=<SubBackward0>)
#
# tensor(-41915.4531, grad_fn=<SubBackward0>)
#
# tensor(-47893.3438, grad_fn=<SubBackward0>)
#
# tensor(-38625.2148, grad_fn=<SubBackward0>)
#
# tensor(-87698.7422, grad_fn=<SubBackward0>)
#
# tensor(-46854.0938, grad_fn=<SubBackward0>)
#
# tensor(-78279.8359, grad_fn=<SubBackward0>)
#
# tensor(-60977.7812, grad_fn=<SubBackward0>)
#
# tensor(-117900.1641, grad_fn=<SubBackward0>)
#
# tensor(-222698.3438, grad_fn=<SubBackward0>)
#
# tensor(-71468.5391, grad_fn=<SubBackward0>)
#
# tensor(-46407.5977, grad_fn=<SubBackward0>)
#
# tensor(-225132.6562, grad_fn=<SubBackward0>)
#
# tensor(-143566.1406, grad_fn=<SubBackward0>)
#
# tensor(-70228.2031, grad_fn=<SubBackward0>)
#
# tensor(-45692.9062, grad_fn=<SubBackward0>)
#
# tensor(-126399.3594, grad_fn=<SubBackward0>)
#
# tensor(-55729.9766, grad_fn=<SubBackward0>)
#
# tensor(-85847.7578, grad_fn=<SubBackward0>)
#
# tensor(-153723.7344, grad_fn=<SubBackward0>)
#
# tensor(-72550.8750, grad_fn=<SubBackward0>)
#
# tensor(-185627.7188, grad_fn=<SubBackward0>)
#
# tensor(-42860.1602, grad_fn=<SubBackward0>)
#
# tensor(-45223.6328, grad_fn=<SubBackward0>)
#
# tensor(-248700.1875, grad_fn=<SubBackward0>)
#
# tensor(-41273.8203, grad_fn=<SubBackward0>)
#
# tensor(-47132.8828, grad_fn=<SubBackward0>)
#
# tensor(-190569.6719, grad_fn=<SubBackward0>)
#
# tensor(-118489.7344, grad_fn=<SubBackward0>)
#
# tensor(-168893.8125, grad_fn=<SubBackward0>)
#
# tensor(-165863.1719, grad_fn=<SubBackward0>)
#
# tensor(-125705.1094, grad_fn=<SubBackward0>)
#
# tensor(-85740.8750, grad_fn=<SubBackward0>)
#
# tensor(-228603.4062, grad_fn=<SubBackward0>)
#
# tensor(-48059.5430, grad_fn=<SubBackward0>)
#
# tensor(-113033.1719, grad_fn=<SubBackward0>)
#
# tensor(-173489.0781, grad_fn=<SubBackward0>)
#
# tensor(-98214.7969, grad_fn=<SubBackward0>)
#
# tensor(-103605.1562, grad_fn=<SubBackward0>)
#
# tensor(-116063.2188, grad_fn=<SubBackward0>)
#
# tensor(-110498.3125, grad_fn=<SubBackward0>)
#
# tensor(-131627.5625, grad_fn=<SubBackward0>)
#
# tensor(-244697.7812, grad_fn=<SubBackward0>)
#
# tensor(-215970.6250, grad_fn=<SubBackward0>)
#
# tensor(-67696.4531, grad_fn=<SubBackward0>)
#
# tensor(-65108.2891, grad_fn=<SubBackward0>)
#
# tensor(-58497.3828, grad_fn=<SubBackward0>)
#
# tensor(-158120.9062, grad_fn=<SubBackward0>)
#
# tensor(-127881.5469, grad_fn=<SubBackward0>)
#
# tensor(-84197.7812, grad_fn=<SubBackward0>)
#
# tensor(-56519.1016, grad_fn=<SubBackward0>)
#
# tensor(-290062.6250, grad_fn=<SubBackward0>)
#
# tensor(-97793.6719, grad_fn=<SubBackward0>)
#
# tensor(-84154.9844, grad_fn=<SubBackward0>)
#
# tensor(-71176.8438, grad_fn=<SubBackward0>)
#
# tensor(-56485.2461, grad_fn=<SubBackward0>)
#
# tensor(-138695.4531, grad_fn=<SubBackward0>)
#
# tensor(-184364.4219, grad_fn=<SubBackward0>)
#
# tensor(-110202.7422, grad_fn=<SubBackward0>)
#
# tensor(-214165.6562, grad_fn=<SubBackward0>)
#
# tensor(-74282.8281, grad_fn=<SubBackward0>)
#
# tensor(-205732.5938, grad_fn=<SubBackward0>)
#
# tensor(-119167.4922, grad_fn=<SubBackward0>)
#
# tensor(-302966.6875, grad_fn=<SubBackward0>)
#
# tensor(-80223.2969, grad_fn=<SubBackward0>)
#
# tensor(-496504.0312, grad_fn=<SubBackward0>)
#
# tensor(-167729.2500, grad_fn=<SubBackward0>)
#
# tensor(-152649.5000, grad_fn=<SubBackward0>)
#
# tensor(-159095.5312, grad_fn=<SubBackward0>)
#
# tensor(-167166.7188, grad_fn=<SubBackward0>)
#
# tensor(-102867.2031, grad_fn=<SubBackward0>)
#
# tensor(-370479.0625, grad_fn=<SubBackward0>)
#
# tensor(-120347.4062, grad_fn=<SubBackward0>)
#
# tensor(-73865.8203, grad_fn=<SubBackward0>)
#
# tensor(-373500.8125, grad_fn=<SubBackward0>)
#
# tensor(-107317.8828, grad_fn=<SubBackward0>)
#
# tensor(-173816.9844, grad_fn=<SubBackward0>)
#
# tensor(-121623.8672, grad_fn=<SubBackward0>)
#
# tensor(-135148.5156, grad_fn=<SubBackward0>)
#
# tensor(-230070.9062, grad_fn=<SubBackward0>)
#
# tensor(-59667.2188, grad_fn=<SubBackward0>)
#
# tensor(-264241.4688, grad_fn=<SubBackward0>)
#
# tensor(-95120.9531, grad_fn=<SubBackward0>)
#
# tensor(-600116.5625, grad_fn=<SubBackward0>)
#
# tensor(-214576.6094, grad_fn=<SubBackward0>)
#
# tensor(-104022.6328, grad_fn=<SubBackward0>)
#
# tensor(-149054.3281, grad_fn=<SubBackward0>)
#
# tensor(-184090.2656, grad_fn=<SubBackward0>)
#
# tensor(-334297.0625, grad_fn=<SubBackward0>)
#
# tensor(-214114.6875, grad_fn=<SubBackward0>)
#
# tensor(-266954.5000, grad_fn=<SubBackward0>)
#
# tensor(-130970.6328, grad_fn=<SubBackward0>)
#
# tensor(-147631.8594, grad_fn=<SubBackward0>)
#
# tensor(-138367.4531, grad_fn=<SubBackward0>)
#
# tensor(-191202.2656, grad_fn=<SubBackward0>)
#
# tensor(-144169.0469, grad_fn=<SubBackward0>)
#
# tensor(-116088.9453, grad_fn=<SubBackward0>)
#
# tensor(-354367.6250, grad_fn=<SubBackward0>)
#
# tensor(-103397.9062, grad_fn=<SubBackward0>)
#
# tensor(-246952.0312, grad_fn=<SubBackward0>)
#
# tensor(-197915.5469, grad_fn=<SubBackward0>)
#
# tensor(-116005.2188, grad_fn=<SubBackward0>)
#
# tensor(-228254.5000, grad_fn=<SubBackward0>)
#
# tensor(-156470.0625, grad_fn=<SubBackward0>)
#
# tensor(-143608.2031, grad_fn=<SubBackward0>)
#
# tensor(-523417.1562, grad_fn=<SubBackward0>)
#
# tensor(-127743.8750, grad_fn=<SubBackward0>)
#
# tensor(-261573.8438, grad_fn=<SubBackward0>)
#
# tensor(-165833.7344, grad_fn=<SubBackward0>)
#
# tensor(-217554.0469, grad_fn=<SubBackward0>)
#
# tensor(-276408.1562, grad_fn=<SubBackward0>)
#
# tensor(-272045.2812, grad_fn=<SubBackward0>)
#
# tensor(-250266.6406, grad_fn=<SubBackward0>)
#
# tensor(-293107.6562, grad_fn=<SubBackward0>)
#
# tensor(-42603.2578, grad_fn=<SubBackward0>)
#
# tensor(-256809.9688, grad_fn=<SubBackward0>)
#
# tensor(-374083.6562, grad_fn=<SubBackward0>)
#
# tensor(-136411.7344, grad_fn=<SubBackward0>)
#
# tensor(-348198.6250, grad_fn=<SubBackward0>)
#
# tensor(-481377.9062, grad_fn=<SubBackward0>)
#
# tensor(-89783.5469, grad_fn=<SubBackward0>)
#
# tensor(-71583.1172, grad_fn=<SubBackward0>)
#
# tensor(-249035.4688, grad_fn=<SubBackward0>)
#
# tensor(-406659.3125, grad_fn=<SubBackward0>)
#
# tensor(-130740.4297, grad_fn=<SubBackward0>)
#
# tensor(-259912.9062, grad_fn=<SubBackward0>)
#
# tensor(-175231.7656, grad_fn=<SubBackward0>)
#
# tensor(-451165.7812, grad_fn=<SubBackward0>)
#
# tensor(-234826.9062, grad_fn=<SubBackward0>)
#
# tensor(-212200.4375, grad_fn=<SubBackward0>)
#
# tensor(-147601.2656, grad_fn=<SubBackward0>)
#
# tensor(-187842.2812, grad_fn=<SubBackward0>)
#
# tensor(-303368.5000, grad_fn=<SubBackward0>)
#
# tensor(-133314.9375, grad_fn=<SubBackward0>)
#
# tensor(-202938.3594, grad_fn=<SubBackward0>)
#
# tensor(-159186.5156, grad_fn=<SubBackward0>)
#
# tensor(-127711.4531, grad_fn=<SubBackward0>)
#
# tensor(-268884.6875, grad_fn=<SubBackward0>)
#
# tensor(-135179.0625, grad_fn=<SubBackward0>)
#
# tensor(-363407.9375, grad_fn=<SubBackward0>)
#
# tensor(-681197.3125, grad_fn=<SubBackward0>)
#
# tensor(-97234.8125, grad_fn=<SubBackward0>)
#
# tensor(-168153.8438, grad_fn=<SubBackward0>)
#
# tensor(-104590.8906, grad_fn=<SubBackward0>)
#
# tensor(-64092.6484, grad_fn=<SubBackward0>)
#
# tensor(-218367.3594, grad_fn=<SubBackward0>)
#
# tensor(-385536.1562, grad_fn=<SubBackward0>)
#
# tensor(-279200.7812, grad_fn=<SubBackward0>)
#
# tensor(-326183.4688, grad_fn=<SubBackward0>)
#
# tensor(-333532.8125, grad_fn=<SubBackward0>)
# tensor(-384155.6875, grad_fn=<SubBackward0>)
#
# tensor(-182206.7812, grad_fn=<SubBackward0>)
#
# tensor(-131651.1250, grad_fn=<SubBackward0>)
#
# tensor(-70834.1328, grad_fn=<SubBackward0>)
#
# tensor(-238906.7500, grad_fn=<SubBackward0>)
#
# tensor(-253330.4844, grad_fn=<SubBackward0>)
#
# tensor(-143605.4688, grad_fn=<SubBackward0>)
#
# tensor(-146482.8281, grad_fn=<SubBackward0>)
#
# tensor(-468878.3438, grad_fn=<SubBackward0>)
#
# tensor(-450307.8125, grad_fn=<SubBackward0>)
#
# tensor(-230747.2188, grad_fn=<SubBackward0>)
#
# tensor(-97046.2969, grad_fn=<SubBackward0>)
#
# tensor(-124639.1797, grad_fn=<SubBackward0>)
#
# tensor(-238847.6719, grad_fn=<SubBackward0>)
#
# tensor(-197050.6562, grad_fn=<SubBackward0>)
#
# tensor(-186992.1250, grad_fn=<SubBackward0>)
#
# tensor(-329714.8125, grad_fn=<SubBackward0>)
#
# tensor(-216126.8906, grad_fn=<SubBackward0>)
#
# tensor(-311599.8125, grad_fn=<SubBackward0>)
#
# tensor(-427322.1875, grad_fn=<SubBackward0>)
#
# tensor(-237040.9844, grad_fn=<SubBackward0>)
#
# tensor(-266540.9062, grad_fn=<SubBackward0>)
#
# tensor(-339209.4688, grad_fn=<SubBackward0>)
#
# tensor(-326627.3750, grad_fn=<SubBackward0>)
#
# tensor(-166000.7344, grad_fn=<SubBackward0>)
#
# tensor(-430895.1562, grad_fn=<SubBackward0>)
#
# tensor(-255868.8750, grad_fn=<SubBackward0>)
#
# tensor(-249248.4688, grad_fn=<SubBackward0>)
#
# tensor(-279409.3438, grad_fn=<SubBackward0>)
#
# tensor(-326687.7188, grad_fn=<SubBackward0>)
#
# tensor(-579007.8125, grad_fn=<SubBackward0>)
#
# tensor(-326719.5938, grad_fn=<SubBackward0>)
#
# tensor(-287366.2500, grad_fn=<SubBackward0>)
#
# tensor(-298663.4688, grad_fn=<SubBackward0>)
#
# tensor(-307038.7188, grad_fn=<SubBackward0>)
#
# tensor(-275080.2812, grad_fn=<SubBackward0>)
#
# tensor(-325614.2500, grad_fn=<SubBackward0>)
#
# tensor(-267523.3438, grad_fn=<SubBackward0>)
#
# tensor(-162637.2188, grad_fn=<SubBackward0>)
#
# tensor(-174151.6562, grad_fn=<SubBackward0>)
#
# tensor(-512347.3750, grad_fn=<SubBackward0>)
#
# tensor(-118891.4531, grad_fn=<SubBackward0>)
#
# tensor(-239223.8438, grad_fn=<SubBackward0>)
#
# tensor(-260946.6250, grad_fn=<SubBackward0>)
#
# tensor(-501324.4375, grad_fn=<SubBackward0>)
#
# tensor(-257981.0312, grad_fn=<SubBackward0>)
#
# tensor(-340867.3750, grad_fn=<SubBackward0>)
#
# tensor(-131355.8594, grad_fn=<SubBackward0>)
#
# tensor(-233578.4219, grad_fn=<SubBackward0>)
#
# tensor(-163267.4688, grad_fn=<SubBackward0>)
#
# tensor(-263120.0312, grad_fn=<SubBackward0>)
#
# tensor(-195726.0156, grad_fn=<SubBackward0>)
#
# tensor(-347849.8750, grad_fn=<SubBackward0>)
#
# tensor(-291705.9375, grad_fn=<SubBackward0>)
#
# tensor(-101947.8750, grad_fn=<SubBackward0>)
#
# tensor(-169457.7812, grad_fn=<SubBackward0>)
#
# tensor(-233191.0625, grad_fn=<SubBackward0>)
#
# tensor(-246868.3750, grad_fn=<SubBackward0>)
#
# tensor(-330303.1875, grad_fn=<SubBackward0>)
#
# tensor(-111316.0781, grad_fn=<SubBackward0>)
#
# tensor(-276913.3125, grad_fn=<SubBackward0>)
#
# tensor(-653817.5625, grad_fn=<SubBackward0>)
#
# tensor(-168943.7812, grad_fn=<SubBackward0>)
#
# tensor(-380756.5000, grad_fn=<SubBackward0>)
#
# tensor(-116286.2656, grad_fn=<SubBackward0>)
#
# tensor(-434190., grad_fn=<SubBackward0>)
#
# tensor(-84223.5078, grad_fn=<SubBackward0>)
#
# tensor(-495722.6250, grad_fn=<SubBackward0>)
#
# tensor(-294985.1250, grad_fn=<SubBackward0>)
#
# tensor(-155401.9531, grad_fn=<SubBackward0>)
#
# tensor(-276601.0312, grad_fn=<SubBackward0>)
#
# tensor(-113740.0703, grad_fn=<SubBackward0>)
#
# tensor(-383098.6562, grad_fn=<SubBackward0>)
#
# tensor(-369313.1875, grad_fn=<SubBackward0>)
#
# tensor(-572146., grad_fn=<SubBackward0>)
#
# tensor(-132585.0625, grad_fn=<SubBackward0>)
#
# tensor(-126886.1016, grad_fn=<SubBackward0>)
#
# tensor(-318198.6250, grad_fn=<SubBackward0>)
#
# tensor(-344411.6562, grad_fn=<SubBackward0>)
#
# tensor(-384132.3750, grad_fn=<SubBackward0>)
#
# tensor(-398741.5625, grad_fn=<SubBackward0>)
#
# tensor(-197967.8438, grad_fn=<SubBackward0>)
#
# tensor(-309496.6875, grad_fn=<SubBackward0>)
#
# tensor(-244016.0625, grad_fn=<SubBackward0>)
#
# tensor(-202882.6562, grad_fn=<SubBackward0>)
#
# tensor(-210592.9219, grad_fn=<SubBackward0>)
#
# tensor(-186194.4531, grad_fn=<SubBackward0>)
#
# tensor(-387618.7500, grad_fn=<SubBackward0>)
#
# tensor(-405542.4688, grad_fn=<SubBackward0>)
#
# tensor(-351346.3125, grad_fn=<SubBackward0>)
#
# tensor(-592107.2500, grad_fn=<SubBackward0>)
#
# tensor(-111466.1094, grad_fn=<SubBackward0>)
#
# tensor(-465567.9375, grad_fn=<SubBackward0>)
#
# tensor(-182457.8750, grad_fn=<SubBackward0>)
#
# tensor(-540068.8750, grad_fn=<SubBackward0>)
#
# tensor(-481305.5625, grad_fn=<SubBackward0>)
#
# tensor(-279769.7500, grad_fn=<SubBackward0>)
#
# tensor(-344452.2500, grad_fn=<SubBackward0>)
#
# tensor(-316260.1250, grad_fn=<SubBackward0>)
#
# tensor(-246379.8594, grad_fn=<SubBackward0>)
#
# tensor(-158207.8594, grad_fn=<SubBackward0>)
#
# tensor(-257172.3438, grad_fn=<SubBackward0>)
#
# tensor(-274974.6562, grad_fn=<SubBackward0>)
#
# tensor(-261407.8906, grad_fn=<SubBackward0>)
#
# tensor(-316577.8125, grad_fn=<SubBackward0>)
#
# tensor(-186864.0156, grad_fn=<SubBackward0>)
#
# tensor(-367048.8750, grad_fn=<SubBackward0>)
#
# tensor(-838165.1875, grad_fn=<SubBackward0>)
#
# tensor(-296425.5938, grad_fn=<SubBackward0>)
#
# tensor(-218589.3906, grad_fn=<SubBackward0>)
#
# tensor(-451855.3438, grad_fn=<SubBackward0>)
#
# tensor(-284187.0625, grad_fn=<SubBackward0>)
#
# tensor(-264509.2500, grad_fn=<SubBackward0>)
#
# tensor(-293680.5312, grad_fn=<SubBackward0>)
#
# tensor(-545035.1875, grad_fn=<SubBackward0>)
#
# tensor(-493363., grad_fn=<SubBackward0>)
#
# tensor(-876440.5625, grad_fn=<SubBackward0>)
#
# tensor(-329627.4062, grad_fn=<SubBackward0>)
#
# tensor(-155249.1719, grad_fn=<SubBackward0>)
#
# tensor(-155576.5781, grad_fn=<SubBackward0>)
#
# tensor(-513771.4375, grad_fn=<SubBackward0>)
#
# tensor(-334761.6250, grad_fn=<SubBackward0>)
#
# tensor(-384729.6875, grad_fn=<SubBackward0>)
#
# tensor(-231447.5312, grad_fn=<SubBackward0>)
#
# tensor(-119850.0703, grad_fn=<SubBackward0>)
#
# tensor(-341462.0625, grad_fn=<SubBackward0>)
#
# tensor(-223506.0938, grad_fn=<SubBackward0>)
#
# tensor(-139387.2812, grad_fn=<SubBackward0>)
#
# tensor(-275662.6250, grad_fn=<SubBackward0>)
#
# tensor(-168264.3750, grad_fn=<SubBackward0>)
#
# tensor(-167490., grad_fn=<SubBackward0>)
#
# tensor(-248909.5312, grad_fn=<SubBackward0>)
#
# tensor(-510789.5625, grad_fn=<SubBackward0>)
#
# tensor(-407430.2812, grad_fn=<SubBackward0>)
#
# tensor(-975582.3125, grad_fn=<SubBackward0>)
#
# tensor(-243997.1406, grad_fn=<SubBackward0>)
#
# tensor(-811735.8125, grad_fn=<SubBackward0>)
#
# tensor(-151792.5781, grad_fn=<SubBackward0>)
#
# tensor(-478780.3438, grad_fn=<SubBackward0>)
#
# tensor(-316049.8125, grad_fn=<SubBackward0>)
#
# tensor(-185917.9531, grad_fn=<SubBackward0>)
#
# tensor(-249671.0312, grad_fn=<SubBackward0>)
#
# tensor(-415043.0938, grad_fn=<SubBackward0>)
#
# tensor(-499524.5938, grad_fn=<SubBackward0>)
#
# tensor(-168092.1406, grad_fn=<SubBackward0>)
#
# tensor(-144445.6875, grad_fn=<SubBackward0>)
#
# tensor(-356973.1875, grad_fn=<SubBackward0>)
#
# tensor(-145043.6719, grad_fn=<SubBackward0>)
#
# tensor(-449046.5938, grad_fn=<SubBackward0>)
#
# tensor(-400601.4375, grad_fn=<SubBackward0>)
#
# tensor(-234290.6562, grad_fn=<SubBackward0>)
#
# tensor(-418671.9062, grad_fn=<SubBackward0>)
#
# tensor(-539153.3750, grad_fn=<SubBackward0>)
#
# tensor(-542402.2500, grad_fn=<SubBackward0>)
#
# tensor(-323534.5312, grad_fn=<SubBackward0>)
#
# tensor(-335869.3750, grad_fn=<SubBackward0>)
#
# tensor(-145029.3750, grad_fn=<SubBackward0>)
#
# tensor(-277408.5000, grad_fn=<SubBackward0>)
#
# tensor(-560102.7500, grad_fn=<SubBackward0>)
#
# tensor(-377993.0312, grad_fn=<SubBackward0>)
#
# tensor(-90668.9375, grad_fn=<SubBackward0>)
#
# tensor(-146310.6562, grad_fn=<SubBackward0>)
#
# tensor(-199524.6250, grad_fn=<SubBackward0>)
#
# tensor(-363725., grad_fn=<SubBackward0>)
#
# tensor(-392463.2500, grad_fn=<SubBackward0>)
#
# tensor(-298958.7812, grad_fn=<SubBackward0>)
#
# tensor(-444227.7188, grad_fn=<SubBackward0>)
#
# tensor(-649691.9375, grad_fn=<SubBackward0>)
#
# tensor(-155366.5312, grad_fn=<SubBackward0>)
#
# tensor(-629870.3750, grad_fn=<SubBackward0>)
#
# tensor(-348699.9062, grad_fn=<SubBackward0>)
#
# tensor(-190390.8125, grad_fn=<SubBackward0>)
#
# tensor(-625431.6250, grad_fn=<SubBackward0>)
#
# tensor(-161316.6094, grad_fn=<SubBackward0>)
#
# tensor(-148576.1719, grad_fn=<SubBackward0>)
#
# tensor(-737879.1875, grad_fn=<SubBackward0>)
# tensor(-431703.0312, grad_fn=<SubBackward0>)
#
# tensor(-401466.1875, grad_fn=<SubBackward0>)
#
# tensor(-324255.2812, grad_fn=<SubBackward0>)
#
# tensor(-369853.5312, grad_fn=<SubBackward0>)
#
# tensor(-361330.0312, grad_fn=<SubBackward0>)
#
# tensor(-242824.6875, grad_fn=<SubBackward0>)
#
# tensor(-287638.2500, grad_fn=<SubBackward0>)
#
# tensor(-281915.0625, grad_fn=<SubBackward0>)
#
# tensor(-434241.7812, grad_fn=<SubBackward0>)
#
# tensor(-353812.5000, grad_fn=<SubBackward0>)
#
# tensor(-229805.7188, grad_fn=<SubBackward0>)
#
# tensor(-576881.3125, grad_fn=<SubBackward0>)
#
# tensor(-485315.6875, grad_fn=<SubBackward0>)
#
# tensor(-325552.4062, grad_fn=<SubBackward0>)
#
# tensor(-262652.9062, grad_fn=<SubBackward0>)
#
# tensor(-686923.3750, grad_fn=<SubBackward0>)
#
# tensor(-295386.7500, grad_fn=<SubBackward0>)
#
# tensor(-237473.4219, grad_fn=<SubBackward0>)
#
# tensor(-285767.8438, grad_fn=<SubBackward0>)
#
# tensor(-190240.3125, grad_fn=<SubBackward0>)
#
# tensor(-462438.6875, grad_fn=<SubBackward0>)
#
# tensor(-608351.3750, grad_fn=<SubBackward0>)
#
# tensor(-248311.7344, grad_fn=<SubBackward0>)
#
# tensor(-126790.2188, grad_fn=<SubBackward0>)
#
# tensor(-148823.3438, grad_fn=<SubBackward0>)
#
# tensor(-344063.8125, grad_fn=<SubBackward0>)
#
# tensor(-322050.9375, grad_fn=<SubBackward0>)
#
# tensor(-513484.8125, grad_fn=<SubBackward0>)
#
# tensor(-422364.6250, grad_fn=<SubBackward0>)
#
# tensor(-215170.6562, grad_fn=<SubBackward0>)
#
# tensor(-291601.5312, grad_fn=<SubBackward0>)
#
# tensor(-455370., grad_fn=<SubBackward0>)
#
# tensor(-510631.6562, grad_fn=<SubBackward0>)
#
# tensor(-151069.4375, grad_fn=<SubBackward0>)
#
# tensor(-276632.4375, grad_fn=<SubBackward0>)
#
# tensor(-469336.9375, grad_fn=<SubBackward0>)
#
# tensor(-283521.4062, grad_fn=<SubBackward0>)
#
# tensor(-736506.9375, grad_fn=<SubBackward0>)
#
# tensor(-152311.0312, grad_fn=<SubBackward0>)
#
# tensor(-317999.8125, grad_fn=<SubBackward0>)
#
# tensor(-552107.8125, grad_fn=<SubBackward0>)
#
# tensor(-401922.5000, grad_fn=<SubBackward0>)
#
# tensor(-408591.8125, grad_fn=<SubBackward0>)
#
# tensor(-238642.6250, grad_fn=<SubBackward0>)
#
# tensor(-513208.0938, grad_fn=<SubBackward0>)
#
# tensor(-241843.1719, grad_fn=<SubBackward0>)
#
# tensor(-466370.4062, grad_fn=<SubBackward0>)
#
# tensor(-300318.5625, grad_fn=<SubBackward0>)
#
# tensor(-683971.2500, grad_fn=<SubBackward0>)
#
# tensor(-290699.6875, grad_fn=<SubBackward0>)
#
# tensor(-350749.3750, grad_fn=<SubBackward0>)
#
# tensor(-342214.9062, grad_fn=<SubBackward0>)
#
# tensor(-595684.5000, grad_fn=<SubBackward0>)
#
# tensor(-418664.5000, grad_fn=<SubBackward0>)
#
# tensor(-375864.5000, grad_fn=<SubBackward0>)
#
# tensor(-484991.7500, grad_fn=<SubBackward0>)
#
# tensor(-172586.5938, grad_fn=<SubBackward0>)
#
# tensor(-429420.5938, grad_fn=<SubBackward0>)
#
# tensor(-233053.6250, grad_fn=<SubBackward0>)
#
# tensor(-732330.2500, grad_fn=<SubBackward0>)
#
# tensor(-394564.1250, grad_fn=<SubBackward0>)
#
# tensor(-240970.5156, grad_fn=<SubBackward0>)
#
# tensor(-295504.7500, grad_fn=<SubBackward0>)
#
# tensor(-273047.8125, grad_fn=<SubBackward0>)
#
# tensor(-600022.6250, grad_fn=<SubBackward0>)
#
# tensor(-388817., grad_fn=<SubBackward0>)
#
# tensor(-516028.0938, grad_fn=<SubBackward0>)
#
# tensor(-495636.7188, grad_fn=<SubBackward0>)
#
# tensor(-707433.8125, grad_fn=<SubBackward0>)
#
# tensor(-741662.2500, grad_fn=<SubBackward0>)
#
# tensor(-293961.1562, grad_fn=<SubBackward0>)
#
# tensor(-392325.1562, grad_fn=<SubBackward0>)
#
# tensor(-441330.6875, grad_fn=<SubBackward0>)
#
# tensor(-776226.2500, grad_fn=<SubBackward0>)
#
# tensor(-658783.1250, grad_fn=<SubBackward0>)
#
# tensor(-394019.7188, grad_fn=<SubBackward0>)
#
# tensor(-442160.6250, grad_fn=<SubBackward0>)
#
# tensor(-257458.2656, grad_fn=<SubBackward0>)
#
# tensor(-386788.9375, grad_fn=<SubBackward0>)
#
# tensor(-216675.8281, grad_fn=<SubBackward0>)
#
# tensor(-347703.1250, grad_fn=<SubBackward0>)
#
# tensor(-457683.1250, grad_fn=<SubBackward0>)
#
# tensor(-316354.1250, grad_fn=<SubBackward0>)
#
# tensor(-389706.5312, grad_fn=<SubBackward0>)
#
# tensor(-719433.3125, grad_fn=<SubBackward0>)
#
# tensor(-815410.1875, grad_fn=<SubBackward0>)
#
# tensor(-335994.4062, grad_fn=<SubBackward0>)
#
# tensor(-268377.2812, grad_fn=<SubBackward0>)
#
# tensor(-592966.5000, grad_fn=<SubBackward0>)
#
# tensor(-434665.4375, grad_fn=<SubBackward0>)
#
# tensor(-339841.3750, grad_fn=<SubBackward0>)
#
# tensor(-949467.6875, grad_fn=<SubBackward0>)
#
# tensor(-1015187.5625, grad_fn=<SubBackward0>)
#
# tensor(-525433.6875, grad_fn=<SubBackward0>)
#
# tensor(-503393.5938, grad_fn=<SubBackward0>)
#
# tensor(-314484., grad_fn=<SubBackward0>)
#
# tensor(-308252.4375, grad_fn=<SubBackward0>)
#
# tensor(-515047., grad_fn=<SubBackward0>)
#
# tensor(-209816.9062, grad_fn=<SubBackward0>)
#
# tensor(-376461.8438, grad_fn=<SubBackward0>)
#
# tensor(-518732.8125, grad_fn=<SubBackward0>)
#
# tensor(-470836.1250, grad_fn=<SubBackward0>)
#
# tensor(-714342.3125, grad_fn=<SubBackward0>)
#
# tensor(-454446.6562, grad_fn=<SubBackward0>)
#
# tensor(-990011.9375, grad_fn=<SubBackward0>)
#
# tensor(-257343.1406, grad_fn=<SubBackward0>)
#
# tensor(-217843.1562, grad_fn=<SubBackward0>)
#
# tensor(-657084.3125, grad_fn=<SubBackward0>)
#
# tensor(-231582.6562, grad_fn=<SubBackward0>)
#
# tensor(-155646.4062, grad_fn=<SubBackward0>)
#
# tensor(-317387.1562, grad_fn=<SubBackward0>)
#
# tensor(-301517.1250, grad_fn=<SubBackward0>)
#
# tensor(-587893.3125, grad_fn=<SubBackward0>)
#
# tensor(-449818.6875, grad_fn=<SubBackward0>)
#
# tensor(-411091.5000, grad_fn=<SubBackward0>)
#
# tensor(-678348.1250, grad_fn=<SubBackward0>)
#
# tensor(-267839.9688, grad_fn=<SubBackward0>)
#
# tensor(-352305.9062, grad_fn=<SubBackward0>)
#
# tensor(-345847., grad_fn=<SubBackward0>)
#
# tensor(-358549.0625, grad_fn=<SubBackward0>)
#
# tensor(-911483., grad_fn=<SubBackward0>)
#
# tensor(-197823.3906, grad_fn=<SubBackward0>)
#
# tensor(-829470., grad_fn=<SubBackward0>)
#
# tensor(-173083.5781, grad_fn=<SubBackward0>)
#
# tensor(-428621.6562, grad_fn=<SubBackward0>)
#
# tensor(-1108193.5000, grad_fn=<SubBackward0>)
#
# tensor(-264587.2188, grad_fn=<SubBackward0>)
#
# tensor(-362786.2812, grad_fn=<SubBackward0>)
#
# tensor(-187316.5156, grad_fn=<SubBackward0>)
#
# tensor(-464694.3125, grad_fn=<SubBackward0>)
#
# tensor(-702505., grad_fn=<SubBackward0>)
#
# tensor(-149701.2656, grad_fn=<SubBackward0>)
#
# tensor(-301939.2188, grad_fn=<SubBackward0>)
#
# tensor(-302411.3125, grad_fn=<SubBackward0>)
#
# tensor(-277354.4062, grad_fn=<SubBackward0>)
#
# tensor(-565292., grad_fn=<SubBackward0>)
#
# tensor(-288674.5625, grad_fn=<SubBackward0>)
#
# tensor(-265633.9375, grad_fn=<SubBackward0>)
#
# tensor(-239449.8281, grad_fn=<SubBackward0>)
#
# tensor(-304816.4375, grad_fn=<SubBackward0>)
#
# tensor(-662062.8750, grad_fn=<SubBackward0>)
#
# tensor(-485127., grad_fn=<SubBackward0>)
#
# tensor(-643613.8125, grad_fn=<SubBackward0>)
#
# tensor(-1025047.2500, grad_fn=<SubBackward0>)
#
# tensor(-216732.0469, grad_fn=<SubBackward0>)
#
# tensor(-242711.5156, grad_fn=<SubBackward0>)
#
# tensor(-894802.2500, grad_fn=<SubBackward0>)
#
# tensor(-529100.2500, grad_fn=<SubBackward0>)
#
# tensor(-140220.5469, grad_fn=<SubBackward0>)
#
# tensor(-244545.9375, grad_fn=<SubBackward0>)
#
# tensor(-300590.5625, grad_fn=<SubBackward0>)
#
# tensor(-439692.0938, grad_fn=<SubBackward0>)
#
# tensor(-212826.4062, grad_fn=<SubBackward0>)
#
# tensor(-620778.4375, grad_fn=<SubBackward0>)
#
# tensor(-769654.1250, grad_fn=<SubBackward0>)
#
# tensor(-434718.1562, grad_fn=<SubBackward0>)
#
# tensor(-390257.8438, grad_fn=<SubBackward0>)
#
# tensor(-402700.6250, grad_fn=<SubBackward0>)
#
# tensor(-469973.8438, grad_fn=<SubBackward0>)
#
# tensor(-872741.8750, grad_fn=<SubBackward0>)
#
# tensor(-326546.6250, grad_fn=<SubBackward0>)
#
# tensor(-443944.8438, grad_fn=<SubBackward0>)
#
# tensor(-786987., grad_fn=<SubBackward0>)
#
# tensor(-261812.5312, grad_fn=<SubBackward0>)
#
# tensor(-1559486.6250, grad_fn=<SubBackward0>)
#
# tensor(-593381.3750, grad_fn=<SubBackward0>)
#
# tensor(-480632.0625, grad_fn=<SubBackward0>)
#
# tensor(-704921.6250, grad_fn=<SubBackward0>)
#
# tensor(-303272.0938, grad_fn=<SubBackward0>)
#
# tensor(-581520.8125, grad_fn=<SubBackward0>)
#
# tensor(-463758.7500, grad_fn=<SubBackward0>)
#
# tensor(-362965.6250, grad_fn=<SubBackward0>)
#
# tensor(-1195545.7500, grad_fn=<SubBackward0>)
#
# tensor(-179410.1406, grad_fn=<SubBackward0>)
#
# tensor(-171819.9688, grad_fn=<SubBackward0>)
# tensor(-399955.8438, grad_fn=<SubBackward0>)
#
# tensor(-186718.7188, grad_fn=<SubBackward0>)
#
# tensor(-309079.1250, grad_fn=<SubBackward0>)
#
# tensor(-307275.8438, grad_fn=<SubBackward0>)
#
# tensor(-392381.8125, grad_fn=<SubBackward0>)
#
# tensor(-144343.3750, grad_fn=<SubBackward0>)
#
# tensor(-362475.7188, grad_fn=<SubBackward0>)
#
# tensor(-293735.3750, grad_fn=<SubBackward0>)
#
# tensor(-473177.1562, grad_fn=<SubBackward0>)
#
# tensor(-536311.4375, grad_fn=<SubBackward0>)
#
# tensor(-461449.1250, grad_fn=<SubBackward0>)
#
# tensor(-419019.8125, grad_fn=<SubBackward0>)
#
# tensor(-242874.2812, grad_fn=<SubBackward0>)
#
# tensor(-139791.0938, grad_fn=<SubBackward0>)
#
# tensor(-979331.6250, grad_fn=<SubBackward0>)
#
# tensor(-644518.4375, grad_fn=<SubBackward0>)
#
# tensor(-572185.1875, grad_fn=<SubBackward0>)
#
# tensor(-344547.0938, grad_fn=<SubBackward0>)
#
# tensor(-340495.9062, grad_fn=<SubBackward0>)
#
# tensor(-696043.6250, grad_fn=<SubBackward0>)
#
# tensor(-895150.6250, grad_fn=<SubBackward0>)
#
# tensor(-1006531.3750, grad_fn=<SubBackward0>)
#
# tensor(-523543.6875, grad_fn=<SubBackward0>)
#
# tensor(-320523.3438, grad_fn=<SubBackward0>)
#
# tensor(-315386.1875, grad_fn=<SubBackward0>)
#
# tensor(-211956.4375, grad_fn=<SubBackward0>)
#
# tensor(-364602.5625, grad_fn=<SubBackward0>)
#
# tensor(-512222.3438, grad_fn=<SubBackward0>)
#
# tensor(-608418.5000, grad_fn=<SubBackward0>)
#
# tensor(-359002., grad_fn=<SubBackward0>)
#
# tensor(-421474.5625, grad_fn=<SubBackward0>)
#
# tensor(-514254.6875, grad_fn=<SubBackward0>)
#
# tensor(-773204.0625, grad_fn=<SubBackward0>)
#
# tensor(-470690.1250, grad_fn=<SubBackward0>)
#
# tensor(-555318.3125, grad_fn=<SubBackward0>)
#
# tensor(-177815.5938, grad_fn=<SubBackward0>)
#
# tensor(-670375.1875, grad_fn=<SubBackward0>)
#
# tensor(-418498.5625, grad_fn=<SubBackward0>)
#
# tensor(-225782.6562, grad_fn=<SubBackward0>)
#
# tensor(-173090.3281, grad_fn=<SubBackward0>)
#
# tensor(-293846.5625, grad_fn=<SubBackward0>)
#
# tensor(-434701.5000, grad_fn=<SubBackward0>)
#
# tensor(-661065.2500, grad_fn=<SubBackward0>)
#
# tensor(-300648.9375, grad_fn=<SubBackward0>)
#
# tensor(-183874.7656, grad_fn=<SubBackward0>)
#
# tensor(-663413.8125, grad_fn=<SubBackward0>)
#
# tensor(-834064.5625, grad_fn=<SubBackward0>)
#
# tensor(-309998.9375, grad_fn=<SubBackward0>)
#
# tensor(-460257.8750, grad_fn=<SubBackward0>)
#
# tensor(-195034.1719, grad_fn=<SubBackward0>)
#
# tensor(-581825.5000, grad_fn=<SubBackward0>)
#
# tensor(-339986.6875, grad_fn=<SubBackward0>)
#
# tensor(-991762.5000, grad_fn=<SubBackward0>)
#
# tensor(-397977.3125, grad_fn=<SubBackward0>)
#
# tensor(-589976.9375, grad_fn=<SubBackward0>)
#
# tensor(-284245.0312, grad_fn=<SubBackward0>)
#
# tensor(-219173.7188, grad_fn=<SubBackward0>)
#
# tensor(-572220.1250, grad_fn=<SubBackward0>)
#
# tensor(-831765.4375, grad_fn=<SubBackward0>)
#
# tensor(-448686.0938, grad_fn=<SubBackward0>)
#
# tensor(-385681.6875, grad_fn=<SubBackward0>)
#
# tensor(-562586.8750, grad_fn=<SubBackward0>)
#
# tensor(-1048305.5625, grad_fn=<SubBackward0>)
#
# tensor(-756676.1875, grad_fn=<SubBackward0>)
#
# tensor(-518930.1250, grad_fn=<SubBackward0>)
#
# tensor(-1071010.6250, grad_fn=<SubBackward0>)
#
# tensor(-2016727.2500, grad_fn=<SubBackward0>)
#
# tensor(-669083., grad_fn=<SubBackward0>)
#
# tensor(-671390.1875, grad_fn=<SubBackward0>)
#
# tensor(-609321., grad_fn=<SubBackward0>)
#
# tensor(-187633.2031, grad_fn=<SubBackward0>)
#
# tensor(-566924., grad_fn=<SubBackward0>)
#
# tensor(-612818.0625, grad_fn=<SubBackward0>)
#
# tensor(-349233.8438, grad_fn=<SubBackward0>)
#
# tensor(-1012677.8125, grad_fn=<SubBackward0>)
#
# tensor(-497654.5938, grad_fn=<SubBackward0>)
#
# tensor(-656524.0625, grad_fn=<SubBackward0>)
#
# tensor(-320926.7188, grad_fn=<SubBackward0>)
#
# tensor(-191248.2031, grad_fn=<SubBackward0>)
#
# tensor(-582096.6875, grad_fn=<SubBackward0>)
#
# tensor(-832769.8125, grad_fn=<SubBackward0>)
#
# tensor(-377658.8750, grad_fn=<SubBackward0>)
#
# tensor(-1096169.2500, grad_fn=<SubBackward0>)
#
# tensor(-441343.5625, grad_fn=<SubBackward0>)
#
# tensor(-641157., grad_fn=<SubBackward0>)
#
# tensor(-538067.1875, grad_fn=<SubBackward0>)
#
# tensor(-457855.5625, grad_fn=<SubBackward0>)
#
# tensor(-365796.9688, grad_fn=<SubBackward0>)
#
# tensor(-235634.6875, grad_fn=<SubBackward0>)
#
# tensor(-666819.0625, grad_fn=<SubBackward0>)
#
# tensor(-698461.9375, grad_fn=<SubBackward0>)
#
# tensor(-393806.6875, grad_fn=<SubBackward0>)
#
# tensor(-1527235.7500, grad_fn=<SubBackward0>)
#
# tensor(-1002582.3750, grad_fn=<SubBackward0>)
#
# tensor(-192267.3281, grad_fn=<SubBackward0>)
#
# tensor(-617855.3750, grad_fn=<SubBackward0>)
#
# tensor(-858336.1250, grad_fn=<SubBackward0>)
#
# tensor(-823962.7500, grad_fn=<SubBackward0>)
#
# tensor(-754452.5000, grad_fn=<SubBackward0>)
#
# tensor(-1184611.2500, grad_fn=<SubBackward0>)
#
# tensor(-1300618.2500, grad_fn=<SubBackward0>)
#
# tensor(-644906.5625, grad_fn=<SubBackward0>)
#
# tensor(-355504.4688, grad_fn=<SubBackward0>)
#
# tensor(-602801.1875, grad_fn=<SubBackward0>)
#
# tensor(-209446.5312, grad_fn=<SubBackward0>)
#
# tensor(-649611.6875, grad_fn=<SubBackward0>)
#
# tensor(-171744.8281, grad_fn=<SubBackward0>)
#
# tensor(-575060.8125, grad_fn=<SubBackward0>)
#
# tensor(-237989.1719, grad_fn=<SubBackward0>)
#
# tensor(-430719.9375, grad_fn=<SubBackward0>)
#
# tensor(-1064957.5000, grad_fn=<SubBackward0>)
#
# tensor(-706361.1875, grad_fn=<SubBackward0>)
#
# tensor(-364240.1562, grad_fn=<SubBackward0>)
#
# tensor(-432603.6875, grad_fn=<SubBackward0>)
#
# tensor(-603101.6875, grad_fn=<SubBackward0>)
#
# tensor(-319428.7500, grad_fn=<SubBackward0>)
#
# tensor(-164279.7969, grad_fn=<SubBackward0>)
#
# tensor(-332515.0938, grad_fn=<SubBackward0>)
#
# tensor(-243549.2656, grad_fn=<SubBackward0>)
#
# tensor(-1029196.6875, grad_fn=<SubBackward0>)
#
# tensor(-1292322.6250, grad_fn=<SubBackward0>)
#
# tensor(-901870.6250, grad_fn=<SubBackward0>)
#
# tensor(-939825.1250, grad_fn=<SubBackward0>)
#
# tensor(-423895., grad_fn=<SubBackward0>)
#
# tensor(-477124.7812, grad_fn=<SubBackward0>)
#
# tensor(-508874.7500, grad_fn=<SubBackward0>)
#
# tensor(-509360.6562, grad_fn=<SubBackward0>)
#
# tensor(-641625.7500, grad_fn=<SubBackward0>)
#
# tensor(-332025.0625, grad_fn=<SubBackward0>)
#
# tensor(-545564.6250, grad_fn=<SubBackward0>)
#
# tensor(-760907.8125, grad_fn=<SubBackward0>)
#
# tensor(-543334.2500, grad_fn=<SubBackward0>)
#
# tensor(-601726.8125, grad_fn=<SubBackward0>)
#
# tensor(-1270459.3750, grad_fn=<SubBackward0>)
#
# tensor(-584678.9375, grad_fn=<SubBackward0>)
#
# tensor(-1480098.2500, grad_fn=<SubBackward0>)
#
# tensor(-295315.7812, grad_fn=<SubBackward0>)
#
# tensor(-248533.8125, grad_fn=<SubBackward0>)
#
# tensor(-857559.5625, grad_fn=<SubBackward0>)
#
# tensor(-676317., grad_fn=<SubBackward0>)
#
# tensor(-414493.2500, grad_fn=<SubBackward0>)
#
# tensor(-832680.3750, grad_fn=<SubBackward0>)
#
# tensor(-1384118.2500, grad_fn=<SubBackward0>)
#
# tensor(-351876.9375, grad_fn=<SubBackward0>)
#
# tensor(-1570537.7500, grad_fn=<SubBackward0>)
#
# tensor(-531154.0625, grad_fn=<SubBackward0>)
#
# tensor(-314282.7812, grad_fn=<SubBackward0>)
#
# tensor(-600158.1250, grad_fn=<SubBackward0>)
#
# tensor(-710773.6250, grad_fn=<SubBackward0>)
#
# tensor(-219887.5312, grad_fn=<SubBackward0>)
#
# tensor(-593161.5000, grad_fn=<SubBackward0>)
#
# tensor(-732401.6250, grad_fn=<SubBackward0>)
#
# tensor(-379978.5625, grad_fn=<SubBackward0>)
#
# tensor(-460247.3125, grad_fn=<SubBackward0>)
#
# tensor(-514669.3438, grad_fn=<SubBackward0>)
#
# tensor(-573721.6250, grad_fn=<SubBackward0>)
#
# tensor(-631078.8750, grad_fn=<SubBackward0>)
#
# tensor(-595646.3125, grad_fn=<SubBackward0>)
#
# tensor(-717377.9375, grad_fn=<SubBackward0>)
#
# tensor(-303836.9375, grad_fn=<SubBackward0>)
#
# tensor(-897695.5000, grad_fn=<SubBackward0>)
#
# tensor(-512154., grad_fn=<SubBackward0>)
#
# tensor(-555326.8125, grad_fn=<SubBackward0>)
#
# tensor(-246763.3438, grad_fn=<SubBackward0>)
#
# tensor(-553327.0625, grad_fn=<SubBackward0>)
#
# tensor(-427260.3750, grad_fn=<SubBackward0>)
#
# tensor(-687257.8125, grad_fn=<SubBackward0>)
#
# tensor(-564058.6250, grad_fn=<SubBackward0>)
#
# tensor(-732585.3125, grad_fn=<SubBackward0>)
#
# tensor(-767093.8125, grad_fn=<SubBackward0>)
#
# tensor(-1117971.7500, grad_fn=<SubBackward0>)
#
# tensor(-1151499.2500, grad_fn=<SubBackward0>)
#
# tensor(-1707198.6250, grad_fn=<SubBackward0>)
#
# tensor(-1853556.1250, grad_fn=<SubBackward0>)
#
# tensor(-339747.1250, grad_fn=<SubBackward0>)
#
# tensor(-393501.5625, grad_fn=<SubBackward0>)
# tensor(-810611.1875, grad_fn=<SubBackward0>)
#
# tensor(-507038.5625, grad_fn=<SubBackward0>)
#
# tensor(-811012.5000, grad_fn=<SubBackward0>)
#
# tensor(-783969.5000, grad_fn=<SubBackward0>)
#
# tensor(-316187.6250, grad_fn=<SubBackward0>)
#
# tensor(-561022.1875, grad_fn=<SubBackward0>)
#
# tensor(-491588.9688, grad_fn=<SubBackward0>)
#
# tensor(-820904.8750, grad_fn=<SubBackward0>)
#
# tensor(-401981.4062, grad_fn=<SubBackward0>)
#
# tensor(-419407.6875, grad_fn=<SubBackward0>)
#
# tensor(-2743053., grad_fn=<SubBackward0>)
#
# tensor(-426824.7812, grad_fn=<SubBackward0>)
#
# tensor(-361092.6250, grad_fn=<SubBackward0>)
#
# tensor(-484389.6250, grad_fn=<SubBackward0>)
#
# tensor(-328666.9062, grad_fn=<SubBackward0>)
#
# tensor(-345019.5000, grad_fn=<SubBackward0>)
#
# tensor(-568103.6250, grad_fn=<SubBackward0>)
#
# tensor(-612214.5625, grad_fn=<SubBackward0>)
#
# tensor(-320689., grad_fn=<SubBackward0>)
#
# tensor(-414406.4375, grad_fn=<SubBackward0>)
#
# tensor(-647053.0625, grad_fn=<SubBackward0>)
#
# tensor(-1346886.2500, grad_fn=<SubBackward0>)
#
# tensor(-1418226.2500, grad_fn=<SubBackward0>)
#
# tensor(-733442.9375, grad_fn=<SubBackward0>)
#
# tensor(-212589.1094, grad_fn=<SubBackward0>)
#
# tensor(-120626.4453, grad_fn=<SubBackward0>)
#
# tensor(-908092.7500, grad_fn=<SubBackward0>)
#
# tensor(-987544.3125, grad_fn=<SubBackward0>)
#
# tensor(-904245.3750, grad_fn=<SubBackward0>)
#
# tensor(-516620.0625, grad_fn=<SubBackward0>)
#
# tensor(-1747440.6250, grad_fn=<SubBackward0>)
#
# tensor(-974263.8750, grad_fn=<SubBackward0>)
#
# tensor(-317402.1875, grad_fn=<SubBackward0>)
#
# tensor(-547717.1250, grad_fn=<SubBackward0>)
#
# tensor(-368850.5312, grad_fn=<SubBackward0>)
#
# tensor(-301666.6250, grad_fn=<SubBackward0>)
#
# tensor(-974560.6250, grad_fn=<SubBackward0>)
#
# tensor(-351011.2188, grad_fn=<SubBackward0>)
#
# tensor(-336347.8750, grad_fn=<SubBackward0>)
#
# tensor(-1100524.1250, grad_fn=<SubBackward0>)
#
# tensor(-529565.1250, grad_fn=<SubBackward0>)
#
# tensor(-722200.9375, grad_fn=<SubBackward0>)
#
# tensor(-393078.6875, grad_fn=<SubBackward0>)
#
# tensor(-280691.6250, grad_fn=<SubBackward0>)
#
# tensor(-553545.5625, grad_fn=<SubBackward0>)
#
# tensor(-322966.6250, grad_fn=<SubBackward0>)
#
# tensor(-1305171.7500, grad_fn=<SubBackward0>)
#
# tensor(-1143853.5000, grad_fn=<SubBackward0>)
#
# tensor(-1098464.5000, grad_fn=<SubBackward0>)
#
# tensor(-548585.8750, grad_fn=<SubBackward0>)
#
# tensor(-391846.4062, grad_fn=<SubBackward0>)
#
# tensor(-663746.7500, grad_fn=<SubBackward0>)
#
# tensor(-173612.5000, grad_fn=<SubBackward0>)
#
# tensor(-410173.5625, grad_fn=<SubBackward0>)
#
# tensor(-487972.3750, grad_fn=<SubBackward0>)
#
# tensor(-1160493.7500, grad_fn=<SubBackward0>)
#
# tensor(-2368934., grad_fn=<SubBackward0>)
#
# tensor(-1086635.6250, grad_fn=<SubBackward0>)
#
# tensor(-515869.3750, grad_fn=<SubBackward0>)
#
# tensor(-595217., grad_fn=<SubBackward0>)
#
# tensor(-442044.1875, grad_fn=<SubBackward0>)
#
# tensor(-343915.3438, grad_fn=<SubBackward0>)
#
# tensor(-355343.7812, grad_fn=<SubBackward0>)
#
# tensor(-396682.8438, grad_fn=<SubBackward0>)
#
# tensor(-1005711.2500, grad_fn=<SubBackward0>)
#
# tensor(-650578.1250, grad_fn=<SubBackward0>)
#
# tensor(-380242.3438, grad_fn=<SubBackward0>)
#
# tensor(-605298.1875, grad_fn=<SubBackward0>)
#
# tensor(-1231948.8750, grad_fn=<SubBackward0>)
#
# tensor(-572477.3750, grad_fn=<SubBackward0>)
#
# tensor(-591644.6250, grad_fn=<SubBackward0>)
#
# tensor(-540540.7500, grad_fn=<SubBackward0>)
#
# tensor(-785399.3125, grad_fn=<SubBackward0>)
#
# tensor(-435331.1875, grad_fn=<SubBackward0>)
#
# tensor(-519555.3125, grad_fn=<SubBackward0>)
#
# tensor(-1005759.3750, grad_fn=<SubBackward0>)
#
# tensor(-627914.9375, grad_fn=<SubBackward0>)
#
# tensor(-1129783.6250, grad_fn=<SubBackward0>)
#
# tensor(-296537.8125, grad_fn=<SubBackward0>)
#
# tensor(-833959.4375, grad_fn=<SubBackward0>)
#
# tensor(-561698., grad_fn=<SubBackward0>)
#
# tensor(-561947.0625, grad_fn=<SubBackward0>)
#
# tensor(-1154194.3750, grad_fn=<SubBackward0>)
#
# tensor(-457959.5625, grad_fn=<SubBackward0>)
#
# tensor(-1047479.8750, grad_fn=<SubBackward0>)
#
# tensor(-767220.6250, grad_fn=<SubBackward0>)
#
# tensor(-340710.1562, grad_fn=<SubBackward0>)
#
# tensor(-1675782., grad_fn=<SubBackward0>)
#
# tensor(-520873.1875, grad_fn=<SubBackward0>)
#
# tensor(-246149.3906, grad_fn=<SubBackward0>)
#
# tensor(-549039.1250, grad_fn=<SubBackward0>)
#
# tensor(-409967.2812, grad_fn=<SubBackward0>)
#
# tensor(-246820.2188, grad_fn=<SubBackward0>)
#
# tensor(-1250141.2500, grad_fn=<SubBackward0>)
#
# tensor(-460918.3125, grad_fn=<SubBackward0>)
#
# tensor(-605071.3750, grad_fn=<SubBackward0>)
#
# tensor(-279192.2500, grad_fn=<SubBackward0>)
#
# tensor(-319050.9062, grad_fn=<SubBackward0>)
#
# tensor(-481390.5938, grad_fn=<SubBackward0>)
#
# tensor(-320209.5938, grad_fn=<SubBackward0>)
#
# tensor(-1189468.2500, grad_fn=<SubBackward0>)
#
# tensor(-215770.8750, grad_fn=<SubBackward0>)
#
# tensor(-1099302., grad_fn=<SubBackward0>)
#
# tensor(-285111.4688, grad_fn=<SubBackward0>)
#
# tensor(-315149.9688, grad_fn=<SubBackward0>)
#
# tensor(-853461.5625, grad_fn=<SubBackward0>)
#
# tensor(-1081134.7500, grad_fn=<SubBackward0>)
#
# tensor(-503420.8750, grad_fn=<SubBackward0>)
#
# tensor(-684821.1875, grad_fn=<SubBackward0>)
#
# tensor(-681256.0625, grad_fn=<SubBackward0>)
#
# tensor(-268960.1250, grad_fn=<SubBackward0>)
#
# tensor(-353524.3125, grad_fn=<SubBackward0>)
#
# tensor(-1244892.7500, grad_fn=<SubBackward0>)
#
# tensor(-360582.5625, grad_fn=<SubBackward0>)
#
# tensor(-1218322.6250, grad_fn=<SubBackward0>)
#
# tensor(-909695.6250, grad_fn=<SubBackward0>)
#
# tensor(-962985.1250, grad_fn=<SubBackward0>)
#
# tensor(-755774.3750, grad_fn=<SubBackward0>)
#
# tensor(-654365., grad_fn=<SubBackward0>)
#
# tensor(-210903.4688, grad_fn=<SubBackward0>)
#
# tensor(-615237.1875, grad_fn=<SubBackward0>)
#
# tensor(-894118.4375, grad_fn=<SubBackward0>)
#
# tensor(-396601.7188, grad_fn=<SubBackward0>)
#
# tensor(-272050.7500, grad_fn=<SubBackward0>)
#
# tensor(-437510.8750, grad_fn=<SubBackward0>)
#
# tensor(-456265.7812, grad_fn=<SubBackward0>)
#
# tensor(-1237237.3750, grad_fn=<SubBackward0>)
#
# tensor(-530902.4375, grad_fn=<SubBackward0>)
#
# tensor(-693303.0625, grad_fn=<SubBackward0>)
#
# tensor(-881788., grad_fn=<SubBackward0>)
#
# tensor(-605881.5000, grad_fn=<SubBackward0>)
#
# tensor(-443200.9375, grad_fn=<SubBackward0>)
#
# tensor(-1493414.6250, grad_fn=<SubBackward0>)
#
# tensor(-1433714.7500, grad_fn=<SubBackward0>)
#
# tensor(-481387.9375, grad_fn=<SubBackward0>)
#
# tensor(-1032542.8750, grad_fn=<SubBackward0>)
#
# tensor(-553784.5000, grad_fn=<SubBackward0>)
#
# tensor(-1389182.3750, grad_fn=<SubBackward0>)
#
# tensor(-275607.0938, grad_fn=<SubBackward0>)
#
# tensor(-1484587.3750, grad_fn=<SubBackward0>)
#
# tensor(-171178.5469, grad_fn=<SubBackward0>)
#
# tensor(-331649., grad_fn=<SubBackward0>)
#
# tensor(-540072., grad_fn=<SubBackward0>)
#
# tensor(-746394.6875, grad_fn=<SubBackward0>)
#
# tensor(-1360679.7500, grad_fn=<SubBackward0>)
#
# tensor(-258573.0625, grad_fn=<SubBackward0>)
#
# tensor(-1568125.5000, grad_fn=<SubBackward0>)
#
# tensor(-248559.6719, grad_fn=<SubBackward0>)
#
# tensor(-222695.9219, grad_fn=<SubBackward0>)
#
# tensor(-383159.8750, grad_fn=<SubBackward0>)
#
# tensor(-3380616., grad_fn=<SubBackward0>)
#
# tensor(-863608.1875, grad_fn=<SubBackward0>)
#
# tensor(-883943.8750, grad_fn=<SubBackward0>)
#
# tensor(-1238979.5000, grad_fn=<SubBackward0>)
#
# tensor(-429959.8125, grad_fn=<SubBackward0>)
#
# tensor(-1106878.7500, grad_fn=<SubBackward0>)
#
# tensor(-1022629.5000, grad_fn=<SubBackward0>)
#
# tensor(-280114.2188, grad_fn=<SubBackward0>)
#
# tensor(-633713.8750, grad_fn=<SubBackward0>)
#
# tensor(-810098.3750, grad_fn=<SubBackward0>)
#
# tensor(-508032.0938, grad_fn=<SubBackward0>)
#
# tensor(-942114.4375, grad_fn=<SubBackward0>)
#
# tensor(-338055.9688, grad_fn=<SubBackward0>)
#
# tensor(-471355.7500, grad_fn=<SubBackward0>)
#
# tensor(-1248021.2500, grad_fn=<SubBackward0>)
#
# tensor(-945404.0625, grad_fn=<SubBackward0>)
#
# tensor(-1037964.3750, grad_fn=<SubBackward0>)
#
# tensor(-795964.1250, grad_fn=<SubBackward0>)
#
# tensor(-919892.1250, grad_fn=<SubBackward0>)
#
# tensor(-844639.7500, grad_fn=<SubBackward0>)
#
# tensor(-348911.5000, grad_fn=<SubBackward0>)
#
# tensor(-531860.0625, grad_fn=<SubBackward0>)
#
# tensor(-846646.5000, grad_fn=<SubBackward0>)
#
# tensor(-341332.8750, grad_fn=<SubBackward0>)
#
# tensor(-839713.2500, grad_fn=<SubBackward0>)
# tensor(-361996.9375, grad_fn=<SubBackward0>)
#
# tensor(-1070950.1250, grad_fn=<SubBackward0>)
#
# tensor(-1378694.8750, grad_fn=<SubBackward0>)
#
# tensor(-688594.6250, grad_fn=<SubBackward0>)
#
# tensor(-145050.6094, grad_fn=<SubBackward0>)
#
# tensor(-577514.5000, grad_fn=<SubBackward0>)
#
# tensor(-694434.0625, grad_fn=<SubBackward0>)
#
# tensor(-1096010.5000, grad_fn=<SubBackward0>)
#
# tensor(-410612.4375, grad_fn=<SubBackward0>)
#
# tensor(-1247628.7500, grad_fn=<SubBackward0>)
#
# tensor(-883536.2500, grad_fn=<SubBackward0>)
#
# tensor(-364376.4688, grad_fn=<SubBackward0>)
#
# tensor(-232061.2500, grad_fn=<SubBackward0>)
#
# tensor(-965774.7500, grad_fn=<SubBackward0>)
#
# tensor(-699139.8750, grad_fn=<SubBackward0>)
#
# tensor(-635118.3750, grad_fn=<SubBackward0>)
#
# tensor(-948576.3750, grad_fn=<SubBackward0>)
#
# tensor(-1525157., grad_fn=<SubBackward0>)
#
# tensor(-472377.6875, grad_fn=<SubBackward0>)
#
# tensor(-673317.3750, grad_fn=<SubBackward0>)
#
# tensor(-819558.4375, grad_fn=<SubBackward0>)
#
# tensor(-601172.6875, grad_fn=<SubBackward0>)
#
# tensor(-585458.9375, grad_fn=<SubBackward0>)
#
# tensor(-817381.8125, grad_fn=<SubBackward0>)
#
# tensor(-583232.3125, grad_fn=<SubBackward0>)
#
# tensor(-383657.8438, grad_fn=<SubBackward0>)
#
# tensor(-675407.6875, grad_fn=<SubBackward0>)
#
# tensor(-820037.7500, grad_fn=<SubBackward0>)
#
# tensor(-428321.0625, grad_fn=<SubBackward0>)
#
# tensor(-408810.9688, grad_fn=<SubBackward0>)
#
# tensor(-664821.6250, grad_fn=<SubBackward0>)
#
# tensor(-703951.2500, grad_fn=<SubBackward0>)
#
# tensor(-1168461.8750, grad_fn=<SubBackward0>)
#
# tensor(-292163.0938, grad_fn=<SubBackward0>)
#
# tensor(-1534085.6250, grad_fn=<SubBackward0>)
#
# tensor(-1317727.6250, grad_fn=<SubBackward0>)
#
# tensor(-385488.9688, grad_fn=<SubBackward0>)
#
# tensor(-1131826.3750, grad_fn=<SubBackward0>)
#
# tensor(-673999.5000, grad_fn=<SubBackward0>)
#
# tensor(-1245687.3750, grad_fn=<SubBackward0>)
#
# tensor(-509947.8438, grad_fn=<SubBackward0>)
#
# tensor(-611092.4375, grad_fn=<SubBackward0>)
#
# tensor(-1581244.5000, grad_fn=<SubBackward0>)
#
# tensor(-1267193.2500, grad_fn=<SubBackward0>)
#
# tensor(-563526.5625, grad_fn=<SubBackward0>)
#
# tensor(-1100000.2500, grad_fn=<SubBackward0>)
#
# tensor(-820209.0625, grad_fn=<SubBackward0>)
#
# tensor(-1345128., grad_fn=<SubBackward0>)
#
# tensor(-610296.5625, grad_fn=<SubBackward0>)
#
# tensor(-667631.3750, grad_fn=<SubBackward0>)
#
# tensor(-974987.7500, grad_fn=<SubBackward0>)
#
# tensor(-716591.1875, grad_fn=<SubBackward0>)
#
# tensor(-1495543.6250, grad_fn=<SubBackward0>)
#
# tensor(-983960.0625, grad_fn=<SubBackward0>)
#
# tensor(-1382063.8750, grad_fn=<SubBackward0>)
#
# tensor(-357478.0625, grad_fn=<SubBackward0>)
#
# tensor(-1839942.1250, grad_fn=<SubBackward0>)
#
# tensor(-2129463.2500, grad_fn=<SubBackward0>)
#
# tensor(-519478.0312, grad_fn=<SubBackward0>)
#
# tensor(-542437.6250, grad_fn=<SubBackward0>)
#
# tensor(-580287.5000, grad_fn=<SubBackward0>)
#
# tensor(-1107377.2500, grad_fn=<SubBackward0>)
#
# tensor(-794797.1250, grad_fn=<SubBackward0>)
#
# tensor(-1227237.1250, grad_fn=<SubBackward0>)
#
# tensor(-1062591.5000, grad_fn=<SubBackward0>)
#
# tensor(-482503.5000, grad_fn=<SubBackward0>)
#
# tensor(-260233.9062, grad_fn=<SubBackward0>)
#
# tensor(-947164.2500, grad_fn=<SubBackward0>)
#
# tensor(-775187.4375, grad_fn=<SubBackward0>)
#
# tensor(-583952., grad_fn=<SubBackward0>)
#
# tensor(-1465412.7500, grad_fn=<SubBackward0>)
#
# tensor(-1755602.5000, grad_fn=<SubBackward0>)
#
# tensor(-410065.9375, grad_fn=<SubBackward0>)
#
# tensor(-467568.8750, grad_fn=<SubBackward0>)
#
# tensor(-558375.0625, grad_fn=<SubBackward0>)
#
# tensor(-424236.7812, grad_fn=<SubBackward0>)
#
# tensor(-567231.1250, grad_fn=<SubBackward0>)
#
# tensor(-2240597., grad_fn=<SubBackward0>)
#
# tensor(-978864.0625, grad_fn=<SubBackward0>)
#
# tensor(-1232258.5000, grad_fn=<SubBackward0>)
#
# tensor(-843806.1250, grad_fn=<SubBackward0>)
#
# tensor(-1531055.1250, grad_fn=<SubBackward0>)
#
# tensor(-802833.3750, grad_fn=<SubBackward0>)
#
# tensor(-1180342.5000, grad_fn=<SubBackward0>)
#
# tensor(-902079.6250, grad_fn=<SubBackward0>)
#
# tensor(-292947.5625, grad_fn=<SubBackward0>)
#
# tensor(-263558.2500, grad_fn=<SubBackward0>)
#
# tensor(-1455496.7500, grad_fn=<SubBackward0>)
#
# tensor(-613516.3125, grad_fn=<SubBackward0>)
#
# tensor(-465328.0625, grad_fn=<SubBackward0>)
#
# tensor(-481329.6875, grad_fn=<SubBackward0>)
#
# tensor(-957822.2500, grad_fn=<SubBackward0>)
#
# tensor(-771558.8750, grad_fn=<SubBackward0>)
#
# tensor(-607689.6875, grad_fn=<SubBackward0>)
#
# tensor(-1524740.6250, grad_fn=<SubBackward0>)
#
# tensor(-968415.4375, grad_fn=<SubBackward0>)
#
# tensor(-2542586., grad_fn=<SubBackward0>)
#
# tensor(-789829.4375, grad_fn=<SubBackward0>)
#
# tensor(-269387.5625, grad_fn=<SubBackward0>)
#
# tensor(-660361.4375, grad_fn=<SubBackward0>)
#
# tensor(-764671.0625, grad_fn=<SubBackward0>)
#
# tensor(-1101084.3750, grad_fn=<SubBackward0>)
#
# tensor(-636577.9375, grad_fn=<SubBackward0>)
#
# tensor(-618486.5625, grad_fn=<SubBackward0>)
#
# tensor(-541182.1875, grad_fn=<SubBackward0>)
#
# tensor(-512466.8750, grad_fn=<SubBackward0>)
#
# tensor(-596964.1250, grad_fn=<SubBackward0>)
#
# tensor(-718797.1875, grad_fn=<SubBackward0>)
#
# tensor(-911750.8125, grad_fn=<SubBackward0>)
#
# tensor(-1495082.6250, grad_fn=<SubBackward0>)
#
# tensor(-257503.5312, grad_fn=<SubBackward0>)
#
# tensor(-738574.1875, grad_fn=<SubBackward0>)
#
# tensor(-415493.4062, grad_fn=<SubBackward0>)
#
# tensor(-467652.3438, grad_fn=<SubBackward0>)
#
# tensor(-1795882.8750, grad_fn=<SubBackward0>)
#
# tensor(-500423.8125, grad_fn=<SubBackward0>)
#
# tensor(-2011003.3750, grad_fn=<SubBackward0>)
#
# tensor(-753531.3750, grad_fn=<SubBackward0>)
#
# tensor(-414948.2812, grad_fn=<SubBackward0>)
#
# tensor(-1596631.3750, grad_fn=<SubBackward0>)
#
# tensor(-679750.4375, grad_fn=<SubBackward0>)
#
# tensor(-448752.7500, grad_fn=<SubBackward0>)
#
# tensor(-4703654.5000, grad_fn=<SubBackward0>)
#
# tensor(-621812.5000, grad_fn=<SubBackward0>)
#
# tensor(-1073195.2500, grad_fn=<SubBackward0>)
#
# tensor(-1288905.2500, grad_fn=<SubBackward0>)
#
# tensor(-695112.1250, grad_fn=<SubBackward0>)
#
# tensor(-600115., grad_fn=<SubBackward0>)
#
# tensor(-1083762.5000, grad_fn=<SubBackward0>)
#
# tensor(-785018.8125, grad_fn=<SubBackward0>)
#
# tensor(-254718.1406, grad_fn=<SubBackward0>)
#
# tensor(-318506.0938, grad_fn=<SubBackward0>)
#
# tensor(-1199518.7500, grad_fn=<SubBackward0>)
#
# tensor(-1164138.1250, grad_fn=<SubBackward0>)
#
# tensor(-708678., grad_fn=<SubBackward0>)
#
# tensor(-1090376.1250, grad_fn=<SubBackward0>)
#
# tensor(-550668., grad_fn=<SubBackward0>)
#
# tensor(-1252822.5000, grad_fn=<SubBackward0>)
#
# tensor(-768720.2500, grad_fn=<SubBackward0>)
#
# tensor(-1086648., grad_fn=<SubBackward0>)
#
# tensor(-766554.1875, grad_fn=<SubBackward0>)
#
# tensor(-895169.6875, grad_fn=<SubBackward0>)
#
# tensor(-723437.8125, grad_fn=<SubBackward0>)
#
# tensor(-835673.0625, grad_fn=<SubBackward0>)
#
# tensor(-382603.3750, grad_fn=<SubBackward0>)
#
# tensor(-361331.5312, grad_fn=<SubBackward0>)
#
# ...
#
# tensor(-1232029.8750, grad_fn=<SubBackward0>)
#
# tensor(-869994.5000, grad_fn=<SubBackward0>)
#
# tensor(-1419831., grad_fn=<SubBackward0>)
#
# tensor(-2273161.5000, grad_fn=<SubBackward0>)
#
# tensor(-994923., grad_fn=<SubBackward0>)
#
# tensor(-651421.8125, grad_fn=<SubBackward0>)
#
# tensor(-526591., grad_fn=<SubBackward0>)
#
# tensor(-3467090.2500, grad_fn=<SubBackward0>)
#
# tensor(-1466572.7500, grad_fn=<SubBackward0>)
#
# tensor(-2330751., grad_fn=<SubBackward0>)
#
# tensor(-1903466., grad_fn=<SubBackward0>)
#
# tensor(-1123476.8750, grad_fn=<SubBackward0>)
#
# tensor(-959084.1875, grad_fn=<SubBackward0>)
#
# tensor(-1218963.7500, grad_fn=<SubBackward0>)
#
# tensor(-1404369.8750, grad_fn=<SubBackward0>)
#
# tensor(-2647963.5000, grad_fn=<SubBackward0>)
#
# tensor(-780017.5625, grad_fn=<SubBackward0>)
#
# tensor(-1388800., grad_fn=<SubBackward0>)
#
# tensor(-1788274.7500, grad_fn=<SubBackward0>)
#
# tensor(-1189206.6250, grad_fn=<SubBackward0>)
#
# tensor(-593006.8125, grad_fn=<SubBackward0>)
#
# tensor(-499996.5000, grad_fn=<SubBackward0>)
#
# tensor(-1796435., grad_fn=<SubBackward0>)
#
# tensor(-1222650.3750, grad_fn=<SubBackward0>)
#
# tensor(-2422860.7500, grad_fn=<SubBackward0>)
#
# tensor(-626112.3125, grad_fn=<SubBackward0>)
#
# tensor(-1669604., grad_fn=<SubBackward0>)
#
# tensor(-705271.6250, grad_fn=<SubBackward0>)
#
# tensor(-1006405.3125, grad_fn=<SubBackward0>)
#
# tensor(-627065.1250, grad_fn=<SubBackward0>)
#
# tensor(-609936.2500, grad_fn=<SubBackward0>)
#
# tensor(-505373.0625, grad_fn=<SubBackward0>)
#
# tensor(-723228.1875, grad_fn=<SubBackward0>)
#
# tensor(-1013971.1250, grad_fn=<SubBackward0>)
#
# tensor(-1357721.7500, grad_fn=<SubBackward0>)
#
# tensor(-470482.9688, grad_fn=<SubBackward0>)
#
# tensor(-703227.7500, grad_fn=<SubBackward0>)
#
# tensor(-953255., grad_fn=<SubBackward0>)
#
# tensor(-3516565., grad_fn=<SubBackward0>)
#
# tensor(-931574.3125, grad_fn=<SubBackward0>)
#
# tensor(-756205.1250, grad_fn=<SubBackward0>)
#
# tensor(-818047.5625, grad_fn=<SubBackward0>)
#
# tensor(-1204054.8750, grad_fn=<SubBackward0>)
#
# tensor(-504104.7812, grad_fn=<SubBackward0>)
#
# tensor(-663625.6250, grad_fn=<SubBackward0>)
#
# tensor(-723036.1875, grad_fn=<SubBackward0>)
#
# tensor(-1480442.2500, grad_fn=<SubBackward0>)
#
# tensor(-923587.1875, grad_fn=<SubBackward0>)
#
# tensor(-821001.0625, grad_fn=<SubBackward0>)
#
# tensor(-3046827., grad_fn=<SubBackward0>)
#
# tensor(-1457236.8750, grad_fn=<SubBackward0>)
#
# tensor(-255121.7812, grad_fn=<SubBackward0>)
#
# tensor(-1528406.2500, grad_fn=<SubBackward0>)
#
# tensor(-1721466.2500, grad_fn=<SubBackward0>)
#
# tensor(-1725464.5000, grad_fn=<SubBackward0>)
#
# tensor(-1620855.5000, grad_fn=<SubBackward0>)
#
# tensor(-1665455.5000, grad_fn=<SubBackward0>)
#
# tensor(-1431667.3750, grad_fn=<SubBackward0>)
#
# tensor(-1511717.1250, grad_fn=<SubBackward0>)
#
# tensor(-625257.1875, grad_fn=<SubBackward0>)
#
# tensor(-713812.3750, grad_fn=<SubBackward0>)
#
# tensor(-925341.7500, grad_fn=<SubBackward0>)
#
# tensor(-1279409.3750, grad_fn=<SubBackward0>)
#
# tensor(-690871.5625, grad_fn=<SubBackward0>)
#
# tensor(-957713.3125, grad_fn=<SubBackward0>)
#
# tensor(-1930949.3750, grad_fn=<SubBackward0>)
#
# tensor(-749091.3750, grad_fn=<SubBackward0>)
#
# tensor(-1004408.6250, grad_fn=<SubBackward0>)
#
# tensor(-671703.2500, grad_fn=<SubBackward0>)
#
# tensor(-1224631.3750, grad_fn=<SubBackward0>)
#
# tensor(-413773.2188, grad_fn=<SubBackward0>)
#
# tensor(-576827.1250, grad_fn=<SubBackward0>)
#
# tensor(-1522107.2500, grad_fn=<SubBackward0>)
#
# tensor(-630464.9375, grad_fn=<SubBackward0>)
#
# tensor(-1157587.3750, grad_fn=<SubBackward0>)
#
# tensor(-2358639.7500, grad_fn=<SubBackward0>)
#
# tensor(-1163942.3750, grad_fn=<SubBackward0>)
#
# tensor(-2388580.7500, grad_fn=<SubBackward0>)
#
# tensor(-717270.4375, grad_fn=<SubBackward0>)
#
# tensor(-743657.5000, grad_fn=<SubBackward0>)
#
# tensor(-3699883., grad_fn=<SubBackward0>)
#
# tensor(-1483001., grad_fn=<SubBackward0>)
#
# tensor(-675487.5625, grad_fn=<SubBackward0>)
#
# tensor(-1213000.8750, grad_fn=<SubBackward0>)
#
# tensor(-1032883.6875, grad_fn=<SubBackward0>)
#
# tensor(-2731241.5000, grad_fn=<SubBackward0>)
#
# tensor(-4152380.2500, grad_fn=<SubBackward0>)
#
# tensor(-1131086.3750, grad_fn=<SubBackward0>)
#
# tensor(-1002154.7500, grad_fn=<SubBackward0>)
#
# tensor(-547549.5000, grad_fn=<SubBackward0>)
#
# tensor(-498348.4062, grad_fn=<SubBackward0>)
#
# tensor(-1947389.3750, grad_fn=<SubBackward0>)
# tensor(-938973., grad_fn=<SubBackward0>)
#
# tensor(-685381., grad_fn=<SubBackward0>)
#
# tensor(-873888.8125, grad_fn=<SubBackward0>)
#
# tensor(-2088688.2500, grad_fn=<SubBackward0>)
#
# tensor(-3961685.7500, grad_fn=<SubBackward0>)
#
# tensor(-1006436., grad_fn=<SubBackward0>)
#
# tensor(-1271649.7500, grad_fn=<SubBackward0>)
#
# tensor(-555409.9375, grad_fn=<SubBackward0>)
#
# tensor(-426879.5000, grad_fn=<SubBackward0>)
#
# tensor(-843994.5000, grad_fn=<SubBackward0>)
#
# tensor(-1672224.2500, grad_fn=<SubBackward0>)
#
# tensor(-1076432.5000, grad_fn=<SubBackward0>)
#
# tensor(-2319914.5000, grad_fn=<SubBackward0>)
#
# tensor(-657329.6875, grad_fn=<SubBackward0>)
#
# tensor(-655484.7500, grad_fn=<SubBackward0>)
#
# tensor(-458797.3438, grad_fn=<SubBackward0>)
#
# tensor(-880504.7500, grad_fn=<SubBackward0>)
#
# tensor(-683920.7500, grad_fn=<SubBackward0>)
#
# tensor(-1144916.8750, grad_fn=<SubBackward0>)
#
# tensor(-1173665.3750, grad_fn=<SubBackward0>)
#
# tensor(-1798610.1250, grad_fn=<SubBackward0>)
#
# tensor(-886062.8125, grad_fn=<SubBackward0>)
#
# tensor(-963260.2500, grad_fn=<SubBackward0>)
#
# tensor(-600454.6250, grad_fn=<SubBackward0>)
#
# tensor(-784539., grad_fn=<SubBackward0>)
#
# tensor(-1183088.2500, grad_fn=<SubBackward0>)
#
# tensor(-2497587.5000, grad_fn=<SubBackward0>)
#
# tensor(-982623.5000, grad_fn=<SubBackward0>)
#
# tensor(-2310171.2500, grad_fn=<SubBackward0>)
#
# tensor(-1578079.2500, grad_fn=<SubBackward0>)
#
# tensor(-704928.3125, grad_fn=<SubBackward0>)
#
# tensor(-982534.5625, grad_fn=<SubBackward0>)
#
# tensor(-754708.8750, grad_fn=<SubBackward0>)
#
# tensor(-1548741.5000, grad_fn=<SubBackward0>)
#
# tensor(-878475.3750, grad_fn=<SubBackward0>)
#
# tensor(-948406.0625, grad_fn=<SubBackward0>)
#
# tensor(-1852294.5000, grad_fn=<SubBackward0>)
#
# tensor(-2758260.5000, grad_fn=<SubBackward0>)
#
# tensor(-624177.3750, grad_fn=<SubBackward0>)
#
# tensor(-931980.9375, grad_fn=<SubBackward0>)
#
# tensor(-1184400.7500, grad_fn=<SubBackward0>)
#
# tensor(-888613.6875, grad_fn=<SubBackward0>)
#
# tensor(-3105816.5000, grad_fn=<SubBackward0>)
#
# tensor(-3314553.5000, grad_fn=<SubBackward0>)
#
# tensor(-691837.1250, grad_fn=<SubBackward0>)
#
# tensor(-1196090.6250, grad_fn=<SubBackward0>)
#
# tensor(-2065292.2500, grad_fn=<SubBackward0>)
#
# tensor(-2271135.5000, grad_fn=<SubBackward0>)
#
# tensor(-709989.6250, grad_fn=<SubBackward0>)
#
# tensor(-993688.6250, grad_fn=<SubBackward0>)
#
# tensor(-600415.1250, grad_fn=<SubBackward0>)
#
# tensor(-2025179.5000, grad_fn=<SubBackward0>)
#
# tensor(-1128196., grad_fn=<SubBackward0>)
#
# tensor(-427848.9688, grad_fn=<SubBackward0>)
#
# tensor(-1110825., grad_fn=<SubBackward0>)
#
# tensor(-1330367., grad_fn=<SubBackward0>)
#
# tensor(-1731724.5000, grad_fn=<SubBackward0>)
#
# tensor(-1604455.7500, grad_fn=<SubBackward0>)
#
# tensor(-872654.1875, grad_fn=<SubBackward0>)
#
# tensor(-1707433.2500, grad_fn=<SubBackward0>)
#
# tensor(-754911.1875, grad_fn=<SubBackward0>)
#
# tensor(-1165747.7500, grad_fn=<SubBackward0>)
#
# tensor(-2572948.7500, grad_fn=<SubBackward0>)
#
# tensor(-1176821.1250, grad_fn=<SubBackward0>)
#
# tensor(-1736632.6250, grad_fn=<SubBackward0>)
#
# tensor(-665339.1875, grad_fn=<SubBackward0>)
#
# tensor(-1057004., grad_fn=<SubBackward0>)
#
# tensor(-435952.2188, grad_fn=<SubBackward0>)
#
# tensor(-2289329.2500, grad_fn=<SubBackward0>)
#
# tensor(-279332.3438, grad_fn=<SubBackward0>)
#
# tensor(-599574.1250, grad_fn=<SubBackward0>)
#
# tensor(-465283.5312, grad_fn=<SubBackward0>)
#
# tensor(-1614266.1250, grad_fn=<SubBackward0>)
#
# tensor(-1360920.6250, grad_fn=<SubBackward0>)
#
# tensor(-888988.6250, grad_fn=<SubBackward0>)
#
# tensor(-548397.6875, grad_fn=<SubBackward0>)
#
# tensor(-466317.0625, grad_fn=<SubBackward0>)
#
# tensor(-2758311.7500, grad_fn=<SubBackward0>)
#
# tensor(-2052692.7500, grad_fn=<SubBackward0>)
#
# tensor(-2390173., grad_fn=<SubBackward0>)
#
# tensor(-1308285.8750, grad_fn=<SubBackward0>)
#
# tensor(-3877718.5000, grad_fn=<SubBackward0>)
#
# tensor(-1128979.8750, grad_fn=<SubBackward0>)
#
# tensor(-923360.3750, grad_fn=<SubBackward0>)
#
# tensor(-1482981.2500, grad_fn=<SubBackward0>)
#
# tensor(-1704730.7500, grad_fn=<SubBackward0>)
#
# tensor(-1703616.8750, grad_fn=<SubBackward0>)
#
# tensor(-1218525.3750, grad_fn=<SubBackward0>)
#
# tensor(-2189566., grad_fn=<SubBackward0>)
#
# tensor(-502915.1250, grad_fn=<SubBackward0>)
#
# tensor(-559496.5625, grad_fn=<SubBackward0>)
#
# tensor(-3299431.5000, grad_fn=<SubBackward0>)
#
# tensor(-808266.3125, grad_fn=<SubBackward0>)
#
# tensor(-1426652.6250, grad_fn=<SubBackward0>)
#
# tensor(-557680.5000, grad_fn=<SubBackward0>)
#
# tensor(-674238.1875, grad_fn=<SubBackward0>)
#
# tensor(-1951051.6250, grad_fn=<SubBackward0>)
#
# tensor(-1006145.8125, grad_fn=<SubBackward0>)
#
# tensor(-1219818.2500, grad_fn=<SubBackward0>)
#
# tensor(-2239313.7500, grad_fn=<SubBackward0>)
#
# tensor(-675721.1250, grad_fn=<SubBackward0>)
#
# tensor(-1050728.7500, grad_fn=<SubBackward0>)
#
# tensor(-408649.5312, grad_fn=<SubBackward0>)
#
# tensor(-1631140.6250, grad_fn=<SubBackward0>)
#
# tensor(-2945845.5000, grad_fn=<SubBackward0>)
#
# tensor(-3416589.5000, grad_fn=<SubBackward0>)
#
# tensor(-915201.3750, grad_fn=<SubBackward0>)
#
# tensor(-1175932.1250, grad_fn=<SubBackward0>)
#
# tensor(-676873.3125, grad_fn=<SubBackward0>)
#
# tensor(-941525.2500, grad_fn=<SubBackward0>)
#
# tensor(-1697378.2500, grad_fn=<SubBackward0>)
#
# tensor(-644746.3750, grad_fn=<SubBackward0>)
#
# tensor(-1056058.5000, grad_fn=<SubBackward0>)
#
# tensor(-481922.2812, grad_fn=<SubBackward0>)
#
# tensor(-2564624., grad_fn=<SubBackward0>)
#
# tensor(-1056406.7500, grad_fn=<SubBackward0>)
#
# tensor(-1057384.2500, grad_fn=<SubBackward0>)
#
# tensor(-440471.8125, grad_fn=<SubBackward0>)
#
# tensor(-1182677., grad_fn=<SubBackward0>)
#
# tensor(-1202136., grad_fn=<SubBackward0>)
#
# tensor(-645335.3750, grad_fn=<SubBackward0>)
#
# tensor(-1266008.6250, grad_fn=<SubBackward0>)
#
# tensor(-2003217.2500, grad_fn=<SubBackward0>)
#
# tensor(-626705.9375, grad_fn=<SubBackward0>)
#
# tensor(-562126.5000, grad_fn=<SubBackward0>)
#
# tensor(-621089.6250, grad_fn=<SubBackward0>)
#
# tensor(-2029862.6250, grad_fn=<SubBackward0>)
#
# tensor(-1539240.1250, grad_fn=<SubBackward0>)
#
# tensor(-1545526.5000, grad_fn=<SubBackward0>)
#
# tensor(-1755377.5000, grad_fn=<SubBackward0>)
#
# tensor(-773581.3125, grad_fn=<SubBackward0>)
#
# tensor(-408120., grad_fn=<SubBackward0>)
#
# tensor(-995903.0625, grad_fn=<SubBackward0>)
#
# tensor(-855047.4375, grad_fn=<SubBackward0>)
#
# tensor(-897913.6250, grad_fn=<SubBackward0>)
#
# tensor(-535372.3125, grad_fn=<SubBackward0>)
#
# tensor(-797582.5625, grad_fn=<SubBackward0>)
#
# tensor(-2156131., grad_fn=<SubBackward0>)
#
# tensor(-1404468.7500, grad_fn=<SubBackward0>)
#
# tensor(-799478.3125, grad_fn=<SubBackward0>)
#
# tensor(-4844620., grad_fn=<SubBackward0>)
#
# tensor(-1090394.3750, grad_fn=<SubBackward0>)
#
# tensor(-417472.1250, grad_fn=<SubBackward0>)
#
# tensor(-1725302.2500, grad_fn=<SubBackward0>)
#
# tensor(-2003132.2500, grad_fn=<SubBackward0>)
#
# tensor(-1487922., grad_fn=<SubBackward0>)
#
# tensor(-810567.7500, grad_fn=<SubBackward0>)
#
# tensor(-1523711.3750, grad_fn=<SubBackward0>)
#
# tensor(-759514.8125, grad_fn=<SubBackward0>)
#
# tensor(-1326547., grad_fn=<SubBackward0>)
#
# tensor(-516297.3750, grad_fn=<SubBackward0>)
#
# tensor(-1177980.6250, grad_fn=<SubBackward0>)
#
# tensor(-4246557.5000, grad_fn=<SubBackward0>)
#
# tensor(-726277.9375, grad_fn=<SubBackward0>)
#
# tensor(-5712091., grad_fn=<SubBackward0>)
#
# tensor(-1855602.7500, grad_fn=<SubBackward0>)
#
# tensor(-1068662.5000, grad_fn=<SubBackward0>)
#
# tensor(-568332.5000, grad_fn=<SubBackward0>)
#
# tensor(-725040.5625, grad_fn=<SubBackward0>)
#
# tensor(-445708.3438, grad_fn=<SubBackward0>)
#
# tensor(-824027.1250, grad_fn=<SubBackward0>)
#
# tensor(-1229699.5000, grad_fn=<SubBackward0>)
#
# tensor(-1429051.6250, grad_fn=<SubBackward0>)
#
# tensor(-955392.8750, grad_fn=<SubBackward0>)
#
# tensor(-1025400.2500, grad_fn=<SubBackward0>)
#
# tensor(-869390.1875, grad_fn=<SubBackward0>)
#
# tensor(-2618650.7500, grad_fn=<SubBackward0>)
#
# tensor(-2029628.3750, grad_fn=<SubBackward0>)
#
# tensor(-1147918., grad_fn=<SubBackward0>)
#
# tensor(-836295.7500, grad_fn=<SubBackward0>)
#
# tensor(-673953.5000, grad_fn=<SubBackward0>)
#
# tensor(-1792560., grad_fn=<SubBackward0>)
#
# tensor(-521032.0938, grad_fn=<SubBackward0>)
#
# tensor(-1632465.8750, grad_fn=<SubBackward0>)
#
# tensor(-397900.1875, grad_fn=<SubBackward0>)
#
# tensor(-697923.4375, grad_fn=<SubBackward0>)
# tensor(-879739.3750, grad_fn=<SubBackward0>)
#
# tensor(-1180061.7500, grad_fn=<SubBackward0>)
#
# tensor(-3024347.7500, grad_fn=<SubBackward0>)
#
# tensor(-487591.9688, grad_fn=<SubBackward0>)
#
# tensor(-1963481.1250, grad_fn=<SubBackward0>)
#
# tensor(-468307.3750, grad_fn=<SubBackward0>)
#
# tensor(-594100.8750, grad_fn=<SubBackward0>)
#
# tensor(-480290.0625, grad_fn=<SubBackward0>)
#
# tensor(-2241008., grad_fn=<SubBackward0>)
#
# tensor(-1901159.2500, grad_fn=<SubBackward0>)
#
# tensor(-1691153.3750, grad_fn=<SubBackward0>)
#
# tensor(-2802173., grad_fn=<SubBackward0>)
#
# tensor(-1090745.3750, grad_fn=<SubBackward0>)
#
# tensor(-1424656.8750, grad_fn=<SubBackward0>)
#
# tensor(-1673474.7500, grad_fn=<SubBackward0>)
#
# tensor(-3785390., grad_fn=<SubBackward0>)
#
# tensor(-809283.4375, grad_fn=<SubBackward0>)
#
# tensor(-1520550.3750, grad_fn=<SubBackward0>)
#
# tensor(-845440.0625, grad_fn=<SubBackward0>)
#
# tensor(-1505564.3750, grad_fn=<SubBackward0>)
#
# tensor(-2412583.7500, grad_fn=<SubBackward0>)
#
# tensor(-1196754., grad_fn=<SubBackward0>)
#
# tensor(-1307746.2500, grad_fn=<SubBackward0>)
#
# tensor(-2015745.7500, grad_fn=<SubBackward0>)
#
# tensor(-1153857.3750, grad_fn=<SubBackward0>)
#
# tensor(-895187.6250, grad_fn=<SubBackward0>)
#
# tensor(-1023562.1875, grad_fn=<SubBackward0>)
#
# tensor(-1277835.5000, grad_fn=<SubBackward0>)
#
# tensor(-452504.7500, grad_fn=<SubBackward0>)
#
# tensor(-2008408.6250, grad_fn=<SubBackward0>)
#
# tensor(-450734.4375, grad_fn=<SubBackward0>)
#
# tensor(-991926.1250, grad_fn=<SubBackward0>)
#
# tensor(-957197.1250, grad_fn=<SubBackward0>)
#
# tensor(-498708.6875, grad_fn=<SubBackward0>)
#
# tensor(-1056064.3750, grad_fn=<SubBackward0>)
#
# tensor(-738739.5625, grad_fn=<SubBackward0>)
#
# tensor(-958929., grad_fn=<SubBackward0>)
#
# tensor(-3068149.5000, grad_fn=<SubBackward0>)
#
# tensor(-1497177., grad_fn=<SubBackward0>)
#
# tensor(-781318.7500, grad_fn=<SubBackward0>)
#
# tensor(-1048202.5625, grad_fn=<SubBackward0>)
#
# tensor(-1927613., grad_fn=<SubBackward0>)
#
# tensor(-2216465.7500, grad_fn=<SubBackward0>)
#
# tensor(-543869.1250, grad_fn=<SubBackward0>)
#
# tensor(-696756.3750, grad_fn=<SubBackward0>)
#
# tensor(-2403127.2500, grad_fn=<SubBackward0>)
#
# tensor(-1173153., grad_fn=<SubBackward0>)
#
# tensor(-1537976.5000, grad_fn=<SubBackward0>)
#
# tensor(-2219380., grad_fn=<SubBackward0>)
#
# tensor(-2153062.2500, grad_fn=<SubBackward0>)
#
# tensor(-1898734., grad_fn=<SubBackward0>)
#
# tensor(-676230.1250, grad_fn=<SubBackward0>)
#
# tensor(-1013191.6875, grad_fn=<SubBackward0>)
#
# tensor(-998381.2500, grad_fn=<SubBackward0>)
#
# tensor(-1096543.6250, grad_fn=<SubBackward0>)
#
# tensor(-1050333.8750, grad_fn=<SubBackward0>)
#
# tensor(-707546.5625, grad_fn=<SubBackward0>)
#
# tensor(-606066.8750, grad_fn=<SubBackward0>)
#
# tensor(-2193998.2500, grad_fn=<SubBackward0>)
#
# tensor(-884963.8750, grad_fn=<SubBackward0>)
#
# tensor(-2368187.2500, grad_fn=<SubBackward0>)
#
# tensor(-1626526.7500, grad_fn=<SubBackward0>)
#
# tensor(-1241583.6250, grad_fn=<SubBackward0>)
#
# tensor(-1021549.7500, grad_fn=<SubBackward0>)
#
# tensor(-969424.2500, grad_fn=<SubBackward0>)
#
# tensor(-1955811.7500, grad_fn=<SubBackward0>)
#
# tensor(-1023217.3750, grad_fn=<SubBackward0>)
#
# tensor(-1527954.3750, grad_fn=<SubBackward0>)
#
# tensor(-537198.1250, grad_fn=<SubBackward0>)
#
# tensor(-1116902.1250, grad_fn=<SubBackward0>)
#
# tensor(-646388.1875, grad_fn=<SubBackward0>)
#
# tensor(-12933347., grad_fn=<SubBackward0>)

# %%
torch.save(BiLSTM_CRF_model, r'D:\BiLSTM_CRF_model')
# Out:
# D:\study\Anaconda\lib\site-packages\torch\serialization.py:250: UserWarning: Couldn't retrieve source code for container of type BiLSTM_CRF. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# 将transtion矩阵初始化为每个时间步各标签概率和为1
